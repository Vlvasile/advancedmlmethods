# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchbnn as bnn
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error, explained_variance_score
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# encoding all variables in the dataset
from sklearn.preprocessing import LabelEncoder

# Get the list of all object columns
object_variables = df.select_dtypes(include=['object']).columns.tolist()

# Find all the boolean columns
bool_variables = [col for col in object_variables if df[col].nunique() == 2]

# Find all the categorical columns with more than 2 unique values
cat_variables = [col for col in object_variables if df[col].nunique() > 2]

encoder = LabelEncoder()
df[bool_variables] = df[bool_variables].apply(encoder.fit_transform)

# get dummies for categorical variables
df = pd.get_dummies(df, columns=cat_variables, drop_first=True)

# %%
# Check for nans
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Split features and target
X = df.drop(columns=['DiabetesPedigreeFunction']).values
y = df['DiabetesPedigreeFunction'].values.reshape(-1, 1)

# Normalize features 
feature_scaler = StandardScaler()
X = feature_scaler.fit_transform(X)

# Normalize target variable
target_scaler = StandardScaler()
y = target_scaler.fit_transform(y)


# First, split the data into train and remaining (validation + test)
X_train, X_remaining, y_train, y_remaining = train_test_split(X, y, test_size=0.3, random_state=42)

# Second, split the remaining data into validation and test sets (e.g., 50% validation, 50% test)
X_val, X_test, y_val, y_test = train_test_split(X_remaining, y_remaining, test_size=0.5, random_state=42)


# Convert to PyTorch tensors
X_train, X_test, X_val = torch.tensor(X_train, dtype=torch.float32), torch.tensor(X_test, dtype=torch.float32), torch.tensor(X_val, dtype=torch.float32)
y_train, y_test, y_val = torch.tensor(y_train, dtype=torch.float32), torch.tensor(y_test, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32) 

# create PyTorch dataloaders, YOU CAN ADJUST THE BATCH SIZES IF YOU WISH
# basic rule: bigger batch size => faster training, but more memory needed
# only shuffle the training dataset, NEVER SHUFFLE TEST/VAL
train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=64, shuffle=True)
test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=64, shuffle=False)
val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=64, shuffle=False)

# %%
# all common hyperparameters we can finetune in the future

# sigma = standard deviation of the noise term (this is often optimized)
# if model is too confident and OVERFITS at the same time, INCREASE sigma
# if predictions are too noisy, too much variation or uncertain  => DECREASE sigma
# COMMON VALUES 0.1 - 0.5

# lambda_kl = amount of KL in the loss function => regularization parameter to avoid OVERFITTING
# if model overfits => increase, if model underfits => decrease
# COMMON VALUES 0.0+ - 0.2

# mu = mean of distribution (you can usually use the defaul 0 in classification)
# if model overfits => decrease mu
# if model underfits => increase mu
# mu = 0 => in the middle of standard distribution (range -3 to +3) => this needs be checked!
# COMMON VALUES: usually 0 in classification

# mc_samples_eval = monte carlo sample size used to approximate distributions in weights
# more samples used => more accurate uncertainty estimation (but heavier to compute)
# if uncertainty is not optimal, try increasing mc_sample -size a little bit
# if model training is too heavy or underfits, you can decrease the sample size
# COMMON VALUES: 25 - 200

mu = 0
sigma = 0.3
lambda_kl = 0.05
mc_samples_eval = 30

# remember to adjust the BNN network structure in the below cell if needed
# amount of layers, layer sizes, amount of dropout regularization etc.

# learning rate is same as in ANN => controls the aggressiveness of optimization
# too large value => model overshoots optimization attempts
# too small value => model learns too slowly
# COMMON VALUES similar to ANN learning rates, small values (0.03 or less), usually 0.1 or less
bnn_learning_rate = 0.01

# weight_decay = regularization applied to model weights (probability distributions)
# penalizes large weights IN ORDER to prevent OVERFITTING
# if model overfits => you can try increasing weight decay, if underfits => try decreasing
# COMMON VALUES are usually quite small, 0.0001 to 0.0005
bnn_weight_decay = 0.0003

# %%
# Bayesian Neural Network -model (BNN) with deeper layers and Monte-Carlo dropout
class BayesianNN(nn.Module):
    def __init__(self, input_dim, output_dim, mu=0, sigma=0.5):
        super().__init__()
        # DEFINE ALL LAYERS THAT WILL BE COMBINED INTO ONE MODEL IN forward()
        # NOTE: Torch requires as to "chain" connected layer => out_features and in_features have to match in connected layers
        # for example "in_features=96, out_features=48" means that previous layers to have out_features of 96
        # and the next layer has to have in features of 48
        self.fc1 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=input_dim, out_features=128)
        self.fc2 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=128, out_features=64)
        self.fc3 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=64, out_features=32)
        self.fc4 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=32, out_features=16)
        self.fc5 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=16, out_features=output_dim)
        self.relu = nn.ReLU()

        # adjust dropout rate to increase regularization
        self.dropout = nn.Dropout(0.3)  

        # THE BATCH NORMALIZATION SIZES HAVE THE MATCH THE OUTPUT OF THE CORRESPONDING LAYER
        self.batch_norm1 = nn.BatchNorm1d(128)
        self.batch_norm2 = nn.BatchNorm1d(64)
        self.batch_norm3 = nn.BatchNorm1d(32)
        self.batch_norm4 = nn.BatchNorm1d(16)
    
    # "forward pass", if mc_dropout = True => adds a dropout layer between the BayesLinear -layers
    def forward(self, x, mc_dropout=False):
        # NOTE: batch normalization helps in stabilizing the training process
        x = self.batch_norm1(self.relu(self.fc1(x))) 
        x = self.dropout(x) if mc_dropout else x
        x = self.batch_norm2(self.relu(self.fc2(x)))
        x = self.dropout(x) if mc_dropout else x
        x = self.batch_norm3(self.relu(self.fc3(x)))
        x = self.dropout(x) if mc_dropout else x
        x = self.batch_norm4(self.relu(self.fc4(x)))
        x = self.dropout(x) if mc_dropout else x
        return self.fc5(x)

# %%
# model, loss, optimizer
# NOTE! Regression, OUTPUT DIMENSION IS 1 VARIABLE!
model = BayesianNN(input_dim=X.shape[1], 
                   output_dim=1,
                   sigma=sigma,
                   mu=mu
                   )

# Loss function for REGRESSION
criterion = nn.MSELoss() 

# Bayesian KL Divergence Loss (efficient regularization for BNN)
bkl_loss = bnn.BKLLoss(reduction='mean')  

# AdamW is common in BNN
optimizer = optim.AdamW(model.parameters(), lr=bnn_learning_rate, weight_decay=bnn_weight_decay)

# %%
# Evaluate function with uncertainty estimation
def evaluate(model, loader, mc_samples=50):
    model.eval() # Set model to evaluation mode
    total_loss = 0
    uncertainties = []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            outputs_list = [model(X_batch, mc_dropout=True) for _ in range(mc_samples)]
            outputs_stack = torch.stack(outputs_list)  # Shape: (mc_samples, batch_size, num_classes)
            outputs_mean = outputs_stack.mean(dim=0)  # Average prediction
            outputs_std = outputs_stack.std(dim=0)  # Standard deviation (uncertainty)

            loss = criterion(outputs_mean, y_batch)
            total_loss += loss.item()


            uncertainties.extend(outputs_std.mean(dim=1).cpu().numpy())  # Store uncertainty per sample

    r2 = r2_score(y_batch.cpu().numpy(), outputs_mean.cpu().numpy())  # Use R^2 score for regression tasks
    avg_loss = total_loss / len(loader) # Average loss across all batches
    avg_uncertainty = np.mean(uncertainties)  # Average uncertainty across all samples

    print(f"Val. confidence score: {r2:.4f}, Val. loss: {avg_loss:.4f}, Avg. Uncertainty: {avg_uncertainty:.4f}")

    return r2, avg_loss, avg_uncertainty, uncertainties  # Return per-sample uncertainty if needed

# Training loop with BKLLoss
def train(model, loader, epochs=50):
    model.train()
    history = {}
    history['train_loss'] = []
    history['val_loss'] = []
    history['r2'] = []
    history['avg_uncertainty'] = []
    for epoch in range(epochs):
        total_loss = 0
        for X_batch, y_batch in loader:
            optimizer.zero_grad()
            outputs = model(X_batch, mc_dropout=True)
            target_loss = criterion(outputs, y_batch) # Compute target loss
            kl_loss = bkl_loss(model)  # Compute BKL loss
            loss = target_loss + lambda_kl * kl_loss  # Combine losses
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f"Epoch {epoch+1}/{epochs}, Training Loss: {total_loss/len(loader):.4f}")

        r2, val_loss, avg_uncertainty, _ = evaluate(model, val_loader)
        history['train_loss'].append(total_loss / len(loader))
        history['val_loss'].append(val_loss)
        history['r2'].append(r2)
        history['avg_uncertainty'].append(avg_uncertainty)

        # set model to training mode for next epoch
        model.train()
        
    return history

# %%
history = train(model, train_loader, epochs=4000)
# Out:
# Epoch 1/4000, Training Loss: 3.7374
# Val. confidence score: -0.1057, Val. loss: 0.9702, Avg. Uncertainty: 1.0094
# Epoch 2/4000, Training Loss: 3.7411
# Val. confidence score: 0.0540, Val. loss: 0.8752, Avg. Uncertainty: 0.7806
# Epoch 3/4000, Training Loss: 2.8285
# Val. confidence score: -0.0139, Val. loss: 0.9023, Avg. Uncertainty: 0.7104
# Epoch 4/4000, Training Loss: 2.1463
# Val. confidence score: -0.0248, Val. loss: 0.9327, Avg. Uncertainty: 0.6442
# Epoch 5/4000, Training Loss: 1.7053
# Val. confidence score: -0.0427, Val. loss: 0.9300, Avg. Uncertainty: 0.5988
# Epoch 6/4000, Training Loss: 2.0000
# Val. confidence score: -0.0451, Val. loss: 0.9216, Avg. Uncertainty: 0.5830
# Epoch 7/4000, Training Loss: 1.7988
# Val. confidence score: 0.0083, Val. loss: 0.9010, Avg. Uncertainty: 0.5284
# Epoch 8/4000, Training Loss: 1.7676
# Val. confidence score: -0.0418, Val. loss: 0.9154, Avg. Uncertainty: 0.5091
# Epoch 9/4000, Training Loss: 1.7393
# Val. confidence score: -0.0203, Val. loss: 0.9019, Avg. Uncertainty: 0.4835
# Epoch 10/4000, Training Loss: 1.5153
# Val. confidence score: -0.0441, Val. loss: 0.9076, Avg. Uncertainty: 0.4878
# Epoch 11/4000, Training Loss: 1.6891
# Val. confidence score: -0.0489, Val. loss: 0.9114, Avg. Uncertainty: 0.4492
# Epoch 12/4000, Training Loss: 1.4718
# Val. confidence score: -0.0574, Val. loss: 0.9210, Avg. Uncertainty: 0.3949
# Epoch 13/4000, Training Loss: 1.6437
# Val. confidence score: -0.0297, Val. loss: 0.9063, Avg. Uncertainty: 0.3938
# Epoch 14/4000, Training Loss: 1.4648
# Val. confidence score: -0.0531, Val. loss: 0.9187, Avg. Uncertainty: 0.3871
# Epoch 15/4000, Training Loss: 1.3506
# Val. confidence score: -0.0009, Val. loss: 0.9052, Avg. Uncertainty: 0.3458
# Epoch 16/4000, Training Loss: 1.2522
# Val. confidence score: -0.0265, Val. loss: 0.9043, Avg. Uncertainty: 0.3368
# Epoch 17/4000, Training Loss: 1.2449
# Val. confidence score: -0.0271, Val. loss: 0.9137, Avg. Uncertainty: 0.3070
# Epoch 18/4000, Training Loss: 1.2996
# Val. confidence score: -0.0328, Val. loss: 0.9068, Avg. Uncertainty: 0.3253
# Epoch 19/4000, Training Loss: 1.3218
# Val. confidence score: -0.0120, Val. loss: 0.8967, Avg. Uncertainty: 0.2959
# Epoch 20/4000, Training Loss: 1.2822
# Val. confidence score: -0.0427, Val. loss: 0.9146, Avg. Uncertainty: 0.2739
# Epoch 21/4000, Training Loss: 1.3618
# Val. confidence score: -0.0168, Val. loss: 0.9066, Avg. Uncertainty: 0.2927
# Epoch 22/4000, Training Loss: 1.2272
# Val. confidence score: -0.0748, Val. loss: 0.9407, Avg. Uncertainty: 0.2770
# Epoch 23/4000, Training Loss: 1.2374
# Val. confidence score: -0.0292, Val. loss: 0.9097, Avg. Uncertainty: 0.2778
# Epoch 24/4000, Training Loss: 1.2789
# Val. confidence score: -0.0361, Val. loss: 0.9150, Avg. Uncertainty: 0.2537
# Epoch 25/4000, Training Loss: 1.2051
# Val. confidence score: -0.0388, Val. loss: 0.9115, Avg. Uncertainty: 0.2648
# Epoch 26/4000, Training Loss: 1.1507
# Val. confidence score: -0.0261, Val. loss: 0.9005, Avg. Uncertainty: 0.2305
# Epoch 27/4000, Training Loss: 1.1227
# Val. confidence score: -0.0172, Val. loss: 0.9034, Avg. Uncertainty: 0.2366
# Epoch 28/4000, Training Loss: 1.1571
# Val. confidence score: -0.0278, Val. loss: 0.9068, Avg. Uncertainty: 0.2136
# Epoch 29/4000, Training Loss: 1.1146
# Val. confidence score: -0.0151, Val. loss: 0.9015, Avg. Uncertainty: 0.2171
# Epoch 30/4000, Training Loss: 1.0763
# Val. confidence score: -0.0216, Val. loss: 0.9058, Avg. Uncertainty: 0.2118
# Epoch 31/4000, Training Loss: 1.0958
# Val. confidence score: -0.0297, Val. loss: 0.9089, Avg. Uncertainty: 0.2107
# Epoch 32/4000, Training Loss: 1.2183
# Val. confidence score: -0.0129, Val. loss: 0.9021, Avg. Uncertainty: 0.2175
# Epoch 33/4000, Training Loss: 1.1113
# Val. confidence score: -0.0320, Val. loss: 0.9115, Avg. Uncertainty: 0.2076
# Epoch 34/4000, Training Loss: 1.1286
# Val. confidence score: -0.0438, Val. loss: 0.9157, Avg. Uncertainty: 0.2076
# Epoch 35/4000, Training Loss: 1.0863
# Val. confidence score: -0.0236, Val. loss: 0.9061, Avg. Uncertainty: 0.1983
# Epoch 36/4000, Training Loss: 1.1000
# Val. confidence score: -0.0163, Val. loss: 0.9014, Avg. Uncertainty: 0.1719
# Epoch 37/4000, Training Loss: 1.0860
# Val. confidence score: -0.0311, Val. loss: 0.9094, Avg. Uncertainty: 0.1637
# Epoch 38/4000, Training Loss: 1.1358
# Val. confidence score: -0.0285, Val. loss: 0.9097, Avg. Uncertainty: 0.1719
# Epoch 39/4000, Training Loss: 1.0836
# Val. confidence score: -0.0266, Val. loss: 0.9082, Avg. Uncertainty: 0.1615
# Epoch 40/4000, Training Loss: 1.1031
# Val. confidence score: -0.0201, Val. loss: 0.9010, Avg. Uncertainty: 0.1632
# Epoch 41/4000, Training Loss: 1.1823
# Val. confidence score: -0.0226, Val. loss: 0.9054, Avg. Uncertainty: 0.1396
# Epoch 42/4000, Training Loss: 1.1430
# Val. confidence score: -0.0328, Val. loss: 0.9092, Avg. Uncertainty: 0.1396
# Epoch 43/4000, Training Loss: 1.1286
# Val. confidence score: -0.0291, Val. loss: 0.9061, Avg. Uncertainty: 0.1512
# Epoch 44/4000, Training Loss: 1.0729
# Val. confidence score: -0.0256, Val. loss: 0.9065, Avg. Uncertainty: 0.1315
# Epoch 45/4000, Training Loss: 1.0592
# Val. confidence score: -0.0362, Val. loss: 0.9129, Avg. Uncertainty: 0.1407
# Epoch 46/4000, Training Loss: 1.0891
# Val. confidence score: -0.0331, Val. loss: 0.9077, Avg. Uncertainty: 0.1383
# Epoch 47/4000, Training Loss: 1.0403
# Val. confidence score: -0.0252, Val. loss: 0.9048, Avg. Uncertainty: 0.1282
# Epoch 48/4000, Training Loss: 1.1104
# Val. confidence score: -0.0225, Val. loss: 0.9063, Avg. Uncertainty: 0.1289
# Epoch 49/4000, Training Loss: 1.1013
# Val. confidence score: -0.0138, Val. loss: 0.8970, Avg. Uncertainty: 0.1364
# Epoch 50/4000, Training Loss: 1.0726
# Val. confidence score: -0.0286, Val. loss: 0.9082, Avg. Uncertainty: 0.1331
# Epoch 51/4000, Training Loss: 1.1284
# Val. confidence score: -0.0318, Val. loss: 0.9093, Avg. Uncertainty: 0.1264
# Epoch 52/4000, Training Loss: 1.0674
# Val. confidence score: -0.0432, Val. loss: 0.9155, Avg. Uncertainty: 0.1154
# Epoch 53/4000, Training Loss: 1.1068
# Val. confidence score: -0.0357, Val. loss: 0.9103, Avg. Uncertainty: 0.1183
# Epoch 54/4000, Training Loss: 1.1874
# Val. confidence score: -0.0152, Val. loss: 0.9001, Avg. Uncertainty: 0.1135
# Epoch 55/4000, Training Loss: 1.1309
# Val. confidence score: -0.0271, Val. loss: 0.9057, Avg. Uncertainty: 0.1064
# Epoch 56/4000, Training Loss: 1.0978
# Val. confidence score: -0.0212, Val. loss: 0.9045, Avg. Uncertainty: 0.1142
# Epoch 57/4000, Training Loss: 1.0697
# Val. confidence score: -0.0219, Val. loss: 0.9032, Avg. Uncertainty: 0.0949
# Epoch 58/4000, Training Loss: 1.0651
# Val. confidence score: -0.0264, Val. loss: 0.9056, Avg. Uncertainty: 0.1143
# Epoch 59/4000, Training Loss: 1.0318
# Val. confidence score: -0.0202, Val. loss: 0.9047, Avg. Uncertainty: 0.1019
# Epoch 60/4000, Training Loss: 1.0509
# Val. confidence score: -0.0227, Val. loss: 0.9046, Avg. Uncertainty: 0.1054
# Epoch 61/4000, Training Loss: 1.1377
# Val. confidence score: -0.0276, Val. loss: 0.9063, Avg. Uncertainty: 0.0960
# Epoch 62/4000, Training Loss: 1.0994
# Val. confidence score: -0.0374, Val. loss: 0.9118, Avg. Uncertainty: 0.0981
# Epoch 63/4000, Training Loss: 1.0769
# Val. confidence score: -0.0261, Val. loss: 0.9058, Avg. Uncertainty: 0.0995
# Epoch 64/4000, Training Loss: 1.0607
# Val. confidence score: -0.0351, Val. loss: 0.9104, Avg. Uncertainty: 0.0856
# Epoch 65/4000, Training Loss: 1.0366
# Val. confidence score: -0.0301, Val. loss: 0.9080, Avg. Uncertainty: 0.0914
# Epoch 66/4000, Training Loss: 1.0540
# Val. confidence score: -0.0340, Val. loss: 0.9111, Avg. Uncertainty: 0.0934
# Epoch 67/4000, Training Loss: 1.1057
# Val. confidence score: -0.0342, Val. loss: 0.9112, Avg. Uncertainty: 0.0879
# Epoch 68/4000, Training Loss: 1.0500
# Val. confidence score: -0.0356, Val. loss: 0.9098, Avg. Uncertainty: 0.0962
# Epoch 69/4000, Training Loss: 1.0300
# Val. confidence score: -0.0328, Val. loss: 0.9087, Avg. Uncertainty: 0.0943
# Epoch 70/4000, Training Loss: 1.0752
# Val. confidence score: -0.0266, Val. loss: 0.9049, Avg. Uncertainty: 0.0951
# Epoch 71/4000, Training Loss: 1.0703
# Val. confidence score: -0.0326, Val. loss: 0.9057, Avg. Uncertainty: 0.0943
# Epoch 72/4000, Training Loss: 1.0754
# Val. confidence score: -0.0312, Val. loss: 0.9069, Avg. Uncertainty: 0.0929
# Epoch 73/4000, Training Loss: 1.1516
# Val. confidence score: -0.0292, Val. loss: 0.9050, Avg. Uncertainty: 0.0972
# Epoch 74/4000, Training Loss: 1.0479
# Val. confidence score: -0.0199, Val. loss: 0.9022, Avg. Uncertainty: 0.0891
# Epoch 75/4000, Training Loss: 1.0710
# Val. confidence score: -0.0247, Val. loss: 0.9023, Avg. Uncertainty: 0.0975
# Epoch 76/4000, Training Loss: 1.0754
# Val. confidence score: -0.0112, Val. loss: 0.8970, Avg. Uncertainty: 0.0840
# Epoch 77/4000, Training Loss: 1.0768
# Val. confidence score: -0.0245, Val. loss: 0.9026, Avg. Uncertainty: 0.0857
# Epoch 78/4000, Training Loss: 1.0511
# Val. confidence score: -0.0180, Val. loss: 0.9008, Avg. Uncertainty: 0.0850
# Epoch 79/4000, Training Loss: 1.1314
# Val. confidence score: -0.0275, Val. loss: 0.9058, Avg. Uncertainty: 0.0816
# Epoch 80/4000, Training Loss: 1.0575
# Val. confidence score: -0.0208, Val. loss: 0.9009, Avg. Uncertainty: 0.0885
# Epoch 81/4000, Training Loss: 1.1465
# Val. confidence score: -0.0139, Val. loss: 0.8966, Avg. Uncertainty: 0.0817
# Epoch 82/4000, Training Loss: 1.1081
# Val. confidence score: -0.0151, Val. loss: 0.8977, Avg. Uncertainty: 0.0876
# Epoch 83/4000, Training Loss: 1.0947
# Val. confidence score: -0.0187, Val. loss: 0.9009, Avg. Uncertainty: 0.0799
# Epoch 84/4000, Training Loss: 1.1344
# Val. confidence score: -0.0263, Val. loss: 0.9033, Avg. Uncertainty: 0.0783
# Epoch 85/4000, Training Loss: 1.0670
# Val. confidence score: -0.0357, Val. loss: 0.9080, Avg. Uncertainty: 0.0800
# Epoch 86/4000, Training Loss: 1.0472
# Val. confidence score: -0.0277, Val. loss: 0.9024, Avg. Uncertainty: 0.0877
# Epoch 87/4000, Training Loss: 1.0230
# Val. confidence score: -0.0276, Val. loss: 0.9052, Avg. Uncertainty: 0.0757
# Epoch 88/4000, Training Loss: 1.0447
# Val. confidence score: -0.0192, Val. loss: 0.8988, Avg. Uncertainty: 0.0830
# Epoch 89/4000, Training Loss: 1.0281
# Val. confidence score: -0.0234, Val. loss: 0.9013, Avg. Uncertainty: 0.0811
# Epoch 90/4000, Training Loss: 1.0316
# Val. confidence score: -0.0293, Val. loss: 0.9033, Avg. Uncertainty: 0.0843
# Epoch 91/4000, Training Loss: 1.0604
# Val. confidence score: -0.0172, Val. loss: 0.8944, Avg. Uncertainty: 0.0848
# Epoch 92/4000, Training Loss: 1.1124
# Val. confidence score: -0.0252, Val. loss: 0.9020, Avg. Uncertainty: 0.0848
# Epoch 93/4000, Training Loss: 1.0396
# Val. confidence score: -0.0139, Val. loss: 0.8944, Avg. Uncertainty: 0.0885
# Epoch 94/4000, Training Loss: 1.0439
# Val. confidence score: -0.0177, Val. loss: 0.8952, Avg. Uncertainty: 0.0769
# Epoch 95/4000, Training Loss: 1.0670
# Val. confidence score: -0.0273, Val. loss: 0.9014, Avg. Uncertainty: 0.0834
# Epoch 96/4000, Training Loss: 1.0425
# Val. confidence score: -0.0159, Val. loss: 0.8938, Avg. Uncertainty: 0.0830
# Epoch 97/4000, Training Loss: 1.0611
# Val. confidence score: -0.0225, Val. loss: 0.8989, Avg. Uncertainty: 0.0859
# Epoch 98/4000, Training Loss: 1.0278
# Val. confidence score: -0.0107, Val. loss: 0.8914, Avg. Uncertainty: 0.0930
# Epoch 99/4000, Training Loss: 1.1045
# Val. confidence score: -0.0137, Val. loss: 0.8953, Avg. Uncertainty: 0.0876
# Epoch 100/4000, Training Loss: 1.0202
# Val. confidence score: -0.0115, Val. loss: 0.8897, Avg. Uncertainty: 0.0910
# Epoch 101/4000, Training Loss: 1.0983
# Val. confidence score: -0.0109, Val. loss: 0.8893, Avg. Uncertainty: 0.0933
# Epoch 102/4000, Training Loss: 1.0405
# Val. confidence score: -0.0097, Val. loss: 0.8892, Avg. Uncertainty: 0.0938
# Epoch 103/4000, Training Loss: 1.0450
# Val. confidence score: -0.0145, Val. loss: 0.8906, Avg. Uncertainty: 0.0990
# Epoch 104/4000, Training Loss: 1.0481
# Val. confidence score: -0.0073, Val. loss: 0.8884, Avg. Uncertainty: 0.1015
# Epoch 105/4000, Training Loss: 1.0990
# Val. confidence score: -0.0035, Val. loss: 0.8843, Avg. Uncertainty: 0.1002
# Epoch 106/4000, Training Loss: 1.0041
# Val. confidence score: -0.0037, Val. loss: 0.8869, Avg. Uncertainty: 0.0905
# Epoch 107/4000, Training Loss: 1.0658
# Val. confidence score: -0.0151, Val. loss: 0.8918, Avg. Uncertainty: 0.0996
# Epoch 108/4000, Training Loss: 1.0598
# Val. confidence score: -0.0170, Val. loss: 0.8891, Avg. Uncertainty: 0.1046
# Epoch 109/4000, Training Loss: 1.0461
# Val. confidence score: -0.0165, Val. loss: 0.8890, Avg. Uncertainty: 0.0953
# Epoch 110/4000, Training Loss: 0.9865
# Val. confidence score: 0.0021, Val. loss: 0.8812, Avg. Uncertainty: 0.1099
# Epoch 111/4000, Training Loss: 1.1395
# Val. confidence score: 0.0065, Val. loss: 0.8763, Avg. Uncertainty: 0.1094
# Epoch 112/4000, Training Loss: 1.0287
# Val. confidence score: 0.0135, Val. loss: 0.8716, Avg. Uncertainty: 0.1021
# Epoch 113/4000, Training Loss: 1.0257
# Val. confidence score: -0.0041, Val. loss: 0.8813, Avg. Uncertainty: 0.0996
# Epoch 114/4000, Training Loss: 1.0341
# Val. confidence score: -0.0022, Val. loss: 0.8822, Avg. Uncertainty: 0.0855
# Epoch 115/4000, Training Loss: 1.0798
# Val. confidence score: -0.0081, Val. loss: 0.8849, Avg. Uncertainty: 0.0896
# Epoch 116/4000, Training Loss: 0.9985
# Val. confidence score: -0.0078, Val. loss: 0.8858, Avg. Uncertainty: 0.0862
# Epoch 117/4000, Training Loss: 1.0542
# Val. confidence score: 0.0070, Val. loss: 0.8770, Avg. Uncertainty: 0.0977
# Epoch 118/4000, Training Loss: 0.9813
# Val. confidence score: 0.0039, Val. loss: 0.8789, Avg. Uncertainty: 0.0830
# Epoch 119/4000, Training Loss: 1.0603
# Val. confidence score: 0.0207, Val. loss: 0.8717, Avg. Uncertainty: 0.1013
# Epoch 120/4000, Training Loss: 0.9670
# Val. confidence score: 0.0214, Val. loss: 0.8672, Avg. Uncertainty: 0.1075
# Epoch 121/4000, Training Loss: 1.0412
# Val. confidence score: 0.0170, Val. loss: 0.8699, Avg. Uncertainty: 0.1081
# Epoch 122/4000, Training Loss: 1.0318
# Val. confidence score: 0.0072, Val. loss: 0.8737, Avg. Uncertainty: 0.1048
# Epoch 123/4000, Training Loss: 1.0158
# Val. confidence score: 0.0154, Val. loss: 0.8688, Avg. Uncertainty: 0.1038
# Epoch 124/4000, Training Loss: 1.0117
# Val. confidence score: 0.0056, Val. loss: 0.8776, Avg. Uncertainty: 0.0960
# Epoch 125/4000, Training Loss: 1.0821
# Val. confidence score: 0.0120, Val. loss: 0.8755, Avg. Uncertainty: 0.0794
# Epoch 126/4000, Training Loss: 1.0154
# Val. confidence score: 0.0112, Val. loss: 0.8764, Avg. Uncertainty: 0.0913
# Epoch 127/4000, Training Loss: 1.0183
# Val. confidence score: 0.0122, Val. loss: 0.8752, Avg. Uncertainty: 0.0843
# Epoch 128/4000, Training Loss: 1.1023
# Val. confidence score: 0.0016, Val. loss: 0.8809, Avg. Uncertainty: 0.0838
# Epoch 129/4000, Training Loss: 1.1184
# Val. confidence score: 0.0057, Val. loss: 0.8790, Avg. Uncertainty: 0.0793
# Epoch 130/4000, Training Loss: 0.9906
# Val. confidence score: 0.0133, Val. loss: 0.8734, Avg. Uncertainty: 0.0918
# Epoch 131/4000, Training Loss: 1.0082
# Val. confidence score: 0.0188, Val. loss: 0.8657, Avg. Uncertainty: 0.0986
# Epoch 132/4000, Training Loss: 1.0385
# Val. confidence score: 0.0097, Val. loss: 0.8758, Avg. Uncertainty: 0.0980
# Epoch 133/4000, Training Loss: 1.1114
# Val. confidence score: 0.0241, Val. loss: 0.8655, Avg. Uncertainty: 0.0985
# Epoch 134/4000, Training Loss: 1.0912
# Val. confidence score: 0.0272, Val. loss: 0.8667, Avg. Uncertainty: 0.0934
# Epoch 135/4000, Training Loss: 1.0155
# Val. confidence score: 0.0293, Val. loss: 0.8642, Avg. Uncertainty: 0.0947
# Epoch 136/4000, Training Loss: 1.0868
# Val. confidence score: 0.0232, Val. loss: 0.8684, Avg. Uncertainty: 0.0893
# Epoch 137/4000, Training Loss: 1.0521
# Val. confidence score: 0.0387, Val. loss: 0.8615, Avg. Uncertainty: 0.0931
# Epoch 138/4000, Training Loss: 1.0998
# Val. confidence score: 0.0480, Val. loss: 0.8568, Avg. Uncertainty: 0.1062
# Epoch 139/4000, Training Loss: 1.1134
# Val. confidence score: 0.0496, Val. loss: 0.8549, Avg. Uncertainty: 0.1029
# Epoch 140/4000, Training Loss: 1.0451
# Val. confidence score: 0.0492, Val. loss: 0.8533, Avg. Uncertainty: 0.1104
# Epoch 141/4000, Training Loss: 1.0055
# Val. confidence score: 0.0488, Val. loss: 0.8522, Avg. Uncertainty: 0.0989
# Epoch 142/4000, Training Loss: 1.0963
# Val. confidence score: 0.0406, Val. loss: 0.8589, Avg. Uncertainty: 0.1029
# Epoch 143/4000, Training Loss: 1.0700
# Val. confidence score: 0.0314, Val. loss: 0.8626, Avg. Uncertainty: 0.0860
# Epoch 144/4000, Training Loss: 1.0777
# Val. confidence score: 0.0438, Val. loss: 0.8564, Avg. Uncertainty: 0.0956
# Epoch 145/4000, Training Loss: 1.1050
# Val. confidence score: 0.0295, Val. loss: 0.8650, Avg. Uncertainty: 0.0941
# Epoch 146/4000, Training Loss: 1.0144
# Val. confidence score: 0.0381, Val. loss: 0.8596, Avg. Uncertainty: 0.0916
# Epoch 147/4000, Training Loss: 1.0010
# Val. confidence score: 0.0156, Val. loss: 0.8739, Avg. Uncertainty: 0.0770
# Epoch 148/4000, Training Loss: 1.0103
# Val. confidence score: 0.0059, Val. loss: 0.8792, Avg. Uncertainty: 0.0806
# Epoch 149/4000, Training Loss: 0.9849
# Val. confidence score: 0.0362, Val. loss: 0.8591, Avg. Uncertainty: 0.0881
# Epoch 150/4000, Training Loss: 1.0119
# Val. confidence score: 0.0305, Val. loss: 0.8615, Avg. Uncertainty: 0.0975
# Epoch 151/4000, Training Loss: 1.0740
# Val. confidence score: 0.0373, Val. loss: 0.8582, Avg. Uncertainty: 0.0918
# Epoch 152/4000, Training Loss: 1.0325
# Val. confidence score: 0.0477, Val. loss: 0.8541, Avg. Uncertainty: 0.0918
# Epoch 153/4000, Training Loss: 1.0688
# Val. confidence score: 0.0414, Val. loss: 0.8583, Avg. Uncertainty: 0.0883
# Epoch 154/4000, Training Loss: 1.0316
# Val. confidence score: 0.0444, Val. loss: 0.8579, Avg. Uncertainty: 0.0719
# Epoch 155/4000, Training Loss: 1.0187
# Val. confidence score: 0.0253, Val. loss: 0.8687, Avg. Uncertainty: 0.0660
# Epoch 156/4000, Training Loss: 0.9681
# Val. confidence score: 0.0250, Val. loss: 0.8657, Avg. Uncertainty: 0.0767
# Epoch 157/4000, Training Loss: 1.0586
# Val. confidence score: 0.0438, Val. loss: 0.8593, Avg. Uncertainty: 0.0951
# Epoch 158/4000, Training Loss: 0.9640
# Val. confidence score: 0.0453, Val. loss: 0.8566, Avg. Uncertainty: 0.0853
# Epoch 159/4000, Training Loss: 0.9747
# Val. confidence score: 0.0403, Val. loss: 0.8592, Avg. Uncertainty: 0.1007
# Epoch 160/4000, Training Loss: 1.0289
# Val. confidence score: 0.0420, Val. loss: 0.8571, Avg. Uncertainty: 0.0877
# Epoch 161/4000, Training Loss: 0.9897
# Val. confidence score: 0.0358, Val. loss: 0.8598, Avg. Uncertainty: 0.0839
# Epoch 162/4000, Training Loss: 1.0329
# Val. confidence score: 0.0317, Val. loss: 0.8638, Avg. Uncertainty: 0.0831
# Epoch 163/4000, Training Loss: 1.0267
# Val. confidence score: 0.0329, Val. loss: 0.8634, Avg. Uncertainty: 0.0769
# Epoch 164/4000, Training Loss: 0.9578
# Val. confidence score: 0.0521, Val. loss: 0.8547, Avg. Uncertainty: 0.0876
# Epoch 165/4000, Training Loss: 1.0495
# Val. confidence score: 0.0405, Val. loss: 0.8587, Avg. Uncertainty: 0.0834
# Epoch 166/4000, Training Loss: 0.9913
# Val. confidence score: 0.0508, Val. loss: 0.8557, Avg. Uncertainty: 0.0827
# Epoch 167/4000, Training Loss: 1.0406
# Val. confidence score: 0.0524, Val. loss: 0.8532, Avg. Uncertainty: 0.0821
# Epoch 168/4000, Training Loss: 1.0061
# Val. confidence score: 0.0327, Val. loss: 0.8640, Avg. Uncertainty: 0.0801
# Epoch 169/4000, Training Loss: 1.0190
# Val. confidence score: 0.0358, Val. loss: 0.8623, Avg. Uncertainty: 0.0797
# Epoch 170/4000, Training Loss: 0.9907
# Val. confidence score: 0.0325, Val. loss: 0.8634, Avg. Uncertainty: 0.0777
# Epoch 171/4000, Training Loss: 0.9811
# Val. confidence score: 0.0379, Val. loss: 0.8605, Avg. Uncertainty: 0.0744
# Epoch 172/4000, Training Loss: 1.0156
# Val. confidence score: 0.0298, Val. loss: 0.8653, Avg. Uncertainty: 0.0677
# Epoch 173/4000, Training Loss: 0.9873
# Val. confidence score: 0.0412, Val. loss: 0.8593, Avg. Uncertainty: 0.0769
# Epoch 174/4000, Training Loss: 1.0009
# Val. confidence score: 0.0356, Val. loss: 0.8634, Avg. Uncertainty: 0.0743
# Epoch 175/4000, Training Loss: 1.0402
# Val. confidence score: 0.0067, Val. loss: 0.8774, Avg. Uncertainty: 0.0757
# Epoch 176/4000, Training Loss: 1.0676
# Val. confidence score: 0.0413, Val. loss: 0.8583, Avg. Uncertainty: 0.0814
# Epoch 177/4000, Training Loss: 0.9822
# Val. confidence score: 0.0398, Val. loss: 0.8605, Avg. Uncertainty: 0.0797
# Epoch 178/4000, Training Loss: 1.0106
# Val. confidence score: 0.0416, Val. loss: 0.8576, Avg. Uncertainty: 0.0921
# Epoch 179/4000, Training Loss: 1.0867
# Val. confidence score: 0.0231, Val. loss: 0.8681, Avg. Uncertainty: 0.0830
# Epoch 180/4000, Training Loss: 1.0696
# Val. confidence score: 0.0391, Val. loss: 0.8594, Avg. Uncertainty: 0.0793
# Epoch 181/4000, Training Loss: 0.9808
# Val. confidence score: 0.0427, Val. loss: 0.8579, Avg. Uncertainty: 0.0795
# Epoch 182/4000, Training Loss: 1.0105
# Val. confidence score: 0.0496, Val. loss: 0.8534, Avg. Uncertainty: 0.0891
# Epoch 183/4000, Training Loss: 1.0075
# Val. confidence score: 0.0360, Val. loss: 0.8619, Avg. Uncertainty: 0.0787
# Epoch 184/4000, Training Loss: 1.0475
# Val. confidence score: 0.0380, Val. loss: 0.8594, Avg. Uncertainty: 0.0757
# Epoch 185/4000, Training Loss: 0.9930
# Val. confidence score: 0.0376, Val. loss: 0.8619, Avg. Uncertainty: 0.0855
# Epoch 186/4000, Training Loss: 0.9778
# Val. confidence score: 0.0445, Val. loss: 0.8573, Avg. Uncertainty: 0.0778
# Epoch 187/4000, Training Loss: 0.9967
# Val. confidence score: 0.0526, Val. loss: 0.8543, Avg. Uncertainty: 0.0861
# Epoch 188/4000, Training Loss: 1.0122
# Val. confidence score: 0.0548, Val. loss: 0.8539, Avg. Uncertainty: 0.0863
# Epoch 189/4000, Training Loss: 0.9871
# Val. confidence score: 0.0566, Val. loss: 0.8534, Avg. Uncertainty: 0.0979
# Epoch 190/4000, Training Loss: 0.9308
# Val. confidence score: 0.0508, Val. loss: 0.8545, Avg. Uncertainty: 0.0824
# Epoch 191/4000, Training Loss: 1.0239
# Val. confidence score: 0.0577, Val. loss: 0.8513, Avg. Uncertainty: 0.0857
# Epoch 192/4000, Training Loss: 1.1270
# Val. confidence score: 0.0303, Val. loss: 0.8660, Avg. Uncertainty: 0.0715
# Epoch 193/4000, Training Loss: 1.0491
# Val. confidence score: 0.0361, Val. loss: 0.8616, Avg. Uncertainty: 0.0716
# Epoch 194/4000, Training Loss: 0.9905
# Val. confidence score: 0.0385, Val. loss: 0.8615, Avg. Uncertainty: 0.0852
# Epoch 195/4000, Training Loss: 1.1155
# Val. confidence score: 0.0413, Val. loss: 0.8587, Avg. Uncertainty: 0.0853
# Epoch 196/4000, Training Loss: 1.0479
# Val. confidence score: 0.0487, Val. loss: 0.8566, Avg. Uncertainty: 0.0745
# Epoch 197/4000, Training Loss: 1.0057
# Val. confidence score: 0.0479, Val. loss: 0.8564, Avg. Uncertainty: 0.0758
# Epoch 198/4000, Training Loss: 1.0370
# Val. confidence score: 0.0404, Val. loss: 0.8604, Avg. Uncertainty: 0.0712
# Epoch 199/4000, Training Loss: 1.0626
# Val. confidence score: 0.0515, Val. loss: 0.8554, Avg. Uncertainty: 0.0788
# Epoch 200/4000, Training Loss: 1.0054
# Val. confidence score: 0.0490, Val. loss: 0.8579, Avg. Uncertainty: 0.0752
# Epoch 201/4000, Training Loss: 0.9847
# Val. confidence score: 0.0625, Val. loss: 0.8515, Avg. Uncertainty: 0.0873
# Epoch 202/4000, Training Loss: 1.0527
# Val. confidence score: 0.0644, Val. loss: 0.8505, Avg. Uncertainty: 0.0868
# Epoch 203/4000, Training Loss: 0.9879
# Val. confidence score: 0.0557, Val. loss: 0.8532, Avg. Uncertainty: 0.0856
# Epoch 204/4000, Training Loss: 0.9519
# Val. confidence score: 0.0703, Val. loss: 0.8464, Avg. Uncertainty: 0.0908
# Epoch 205/4000, Training Loss: 1.0813
# Val. confidence score: 0.0571, Val. loss: 0.8527, Avg. Uncertainty: 0.0933
# Epoch 206/4000, Training Loss: 1.0034
# Val. confidence score: 0.0701, Val. loss: 0.8467, Avg. Uncertainty: 0.0975
# Epoch 207/4000, Training Loss: 0.9982
# Val. confidence score: 0.0580, Val. loss: 0.8516, Avg. Uncertainty: 0.0833
# Epoch 208/4000, Training Loss: 1.0355
# Val. confidence score: 0.0657, Val. loss: 0.8482, Avg. Uncertainty: 0.0827
# Epoch 209/4000, Training Loss: 1.0300
# Val. confidence score: 0.0628, Val. loss: 0.8523, Avg. Uncertainty: 0.0793
# Epoch 210/4000, Training Loss: 1.0097
# Val. confidence score: 0.0640, Val. loss: 0.8513, Avg. Uncertainty: 0.0924
# Epoch 211/4000, Training Loss: 0.9650
# Val. confidence score: 0.0452, Val. loss: 0.8630, Avg. Uncertainty: 0.0894
# Epoch 212/4000, Training Loss: 1.0254
# Val. confidence score: 0.0319, Val. loss: 0.8669, Avg. Uncertainty: 0.0709
# Epoch 213/4000, Training Loss: 0.9872
# Val. confidence score: 0.0562, Val. loss: 0.8535, Avg. Uncertainty: 0.0749
# Epoch 214/4000, Training Loss: 0.9785
# Val. confidence score: 0.0508, Val. loss: 0.8545, Avg. Uncertainty: 0.0619
# Epoch 215/4000, Training Loss: 1.0444
# Val. confidence score: 0.0353, Val. loss: 0.8623, Avg. Uncertainty: 0.0721
# Epoch 216/4000, Training Loss: 0.9979
# Val. confidence score: 0.0447, Val. loss: 0.8582, Avg. Uncertainty: 0.0751
# Epoch 217/4000, Training Loss: 1.1066
# Val. confidence score: 0.0479, Val. loss: 0.8568, Avg. Uncertainty: 0.0707
# Epoch 218/4000, Training Loss: 0.9875
# Val. confidence score: 0.0510, Val. loss: 0.8569, Avg. Uncertainty: 0.0777
# Epoch 219/4000, Training Loss: 1.0371
# Val. confidence score: 0.0628, Val. loss: 0.8504, Avg. Uncertainty: 0.0824
# Epoch 220/4000, Training Loss: 1.0569
# Val. confidence score: 0.0580, Val. loss: 0.8502, Avg. Uncertainty: 0.0718
# Epoch 221/4000, Training Loss: 1.0057
# Val. confidence score: 0.0579, Val. loss: 0.8530, Avg. Uncertainty: 0.0820
# Epoch 222/4000, Training Loss: 1.0257
# Val. confidence score: 0.0653, Val. loss: 0.8492, Avg. Uncertainty: 0.0826
# Epoch 223/4000, Training Loss: 1.0074
# Val. confidence score: 0.0524, Val. loss: 0.8566, Avg. Uncertainty: 0.0807
# Epoch 224/4000, Training Loss: 0.9840
# Val. confidence score: 0.0427, Val. loss: 0.8610, Avg. Uncertainty: 0.0793
# Epoch 225/4000, Training Loss: 0.9637
# Val. confidence score: 0.0326, Val. loss: 0.8662, Avg. Uncertainty: 0.0744
# Epoch 226/4000, Training Loss: 1.0092
# Val. confidence score: 0.0519, Val. loss: 0.8561, Avg. Uncertainty: 0.0698
# Epoch 227/4000, Training Loss: 0.9854
# Val. confidence score: 0.0655, Val. loss: 0.8514, Avg. Uncertainty: 0.0801
# Epoch 228/4000, Training Loss: 0.9729
# Val. confidence score: 0.0426, Val. loss: 0.8606, Avg. Uncertainty: 0.0783
# Epoch 229/4000, Training Loss: 0.9622
# Val. confidence score: 0.0466, Val. loss: 0.8613, Avg. Uncertainty: 0.0804
# Epoch 230/4000, Training Loss: 0.9935
# Val. confidence score: 0.0528, Val. loss: 0.8588, Avg. Uncertainty: 0.0858
# Epoch 231/4000, Training Loss: 1.0536
# Val. confidence score: 0.0444, Val. loss: 0.8626, Avg. Uncertainty: 0.0833
# Epoch 232/4000, Training Loss: 0.9817
# Val. confidence score: 0.0591, Val. loss: 0.8551, Avg. Uncertainty: 0.0801
# Epoch 233/4000, Training Loss: 1.0437
# Val. confidence score: 0.0463, Val. loss: 0.8593, Avg. Uncertainty: 0.0695
# Epoch 234/4000, Training Loss: 1.0064
# Val. confidence score: 0.0386, Val. loss: 0.8631, Avg. Uncertainty: 0.0654
# Epoch 235/4000, Training Loss: 0.9682
# Val. confidence score: 0.0339, Val. loss: 0.8658, Avg. Uncertainty: 0.0691
# Epoch 236/4000, Training Loss: 1.0489
# Val. confidence score: 0.0390, Val. loss: 0.8626, Avg. Uncertainty: 0.0708
# Epoch 237/4000, Training Loss: 1.0115
# Val. confidence score: 0.0577, Val. loss: 0.8554, Avg. Uncertainty: 0.0704
# Epoch 238/4000, Training Loss: 0.9856
# Val. confidence score: 0.0500, Val. loss: 0.8578, Avg. Uncertainty: 0.0701
# Epoch 239/4000, Training Loss: 0.9680
# Val. confidence score: 0.0517, Val. loss: 0.8581, Avg. Uncertainty: 0.0724
# Epoch 240/4000, Training Loss: 0.9878
# Val. confidence score: 0.0536, Val. loss: 0.8572, Avg. Uncertainty: 0.0760
# Epoch 241/4000, Training Loss: 0.9688
# Val. confidence score: 0.0563, Val. loss: 0.8565, Avg. Uncertainty: 0.0830
# Epoch 242/4000, Training Loss: 0.9578
# Val. confidence score: 0.0393, Val. loss: 0.8650, Avg. Uncertainty: 0.0811
# Epoch 243/4000, Training Loss: 0.9718
# Val. confidence score: 0.0510, Val. loss: 0.8583, Avg. Uncertainty: 0.0711
# Epoch 244/4000, Training Loss: 0.9655
# Val. confidence score: 0.0572, Val. loss: 0.8555, Avg. Uncertainty: 0.0787
# Epoch 245/4000, Training Loss: 0.9731
# Val. confidence score: 0.0439, Val. loss: 0.8614, Avg. Uncertainty: 0.0816
# Epoch 246/4000, Training Loss: 1.1073
# Val. confidence score: 0.0528, Val. loss: 0.8542, Avg. Uncertainty: 0.0818
# Epoch 247/4000, Training Loss: 0.9988
# Val. confidence score: 0.0704, Val. loss: 0.8567, Avg. Uncertainty: 0.0852
# Epoch 248/4000, Training Loss: 0.9890
# Val. confidence score: 0.0531, Val. loss: 0.8564, Avg. Uncertainty: 0.0799
# Epoch 249/4000, Training Loss: 1.0454
# Val. confidence score: 0.0374, Val. loss: 0.8623, Avg. Uncertainty: 0.0698
# Epoch 250/4000, Training Loss: 1.0371
# Val. confidence score: 0.0485, Val. loss: 0.8573, Avg. Uncertainty: 0.0804
# Epoch 251/4000, Training Loss: 1.0393
# Val. confidence score: 0.0582, Val. loss: 0.8542, Avg. Uncertainty: 0.0743
# Epoch 252/4000, Training Loss: 1.0412
# Val. confidence score: 0.0559, Val. loss: 0.8556, Avg. Uncertainty: 0.0778
# Epoch 253/4000, Training Loss: 1.0254
# Val. confidence score: 0.0587, Val. loss: 0.8538, Avg. Uncertainty: 0.0851
# Epoch 254/4000, Training Loss: 1.0341
# Val. confidence score: 0.0221, Val. loss: 0.8725, Avg. Uncertainty: 0.0628
# Epoch 255/4000, Training Loss: 1.0872
# Val. confidence score: 0.0328, Val. loss: 0.8644, Avg. Uncertainty: 0.0736
# Epoch 256/4000, Training Loss: 0.9839
# Val. confidence score: 0.0506, Val. loss: 0.8563, Avg. Uncertainty: 0.0766
# Epoch 257/4000, Training Loss: 0.9811
# Val. confidence score: 0.0407, Val. loss: 0.8653, Avg. Uncertainty: 0.0867
# Epoch 258/4000, Training Loss: 1.1018
# Val. confidence score: 0.0288, Val. loss: 0.8729, Avg. Uncertainty: 0.0808
# Epoch 259/4000, Training Loss: 1.0136
# Val. confidence score: 0.0456, Val. loss: 0.8612, Avg. Uncertainty: 0.0762
# Epoch 260/4000, Training Loss: 1.0529
# Val. confidence score: 0.0496, Val. loss: 0.8604, Avg. Uncertainty: 0.0729
# Epoch 261/4000, Training Loss: 0.9464
# Val. confidence score: 0.0470, Val. loss: 0.8597, Avg. Uncertainty: 0.0802
# Epoch 262/4000, Training Loss: 0.9485
# Val. confidence score: 0.0377, Val. loss: 0.8714, Avg. Uncertainty: 0.1002
# Epoch 263/4000, Training Loss: 0.9968
# Val. confidence score: 0.0436, Val. loss: 0.8616, Avg. Uncertainty: 0.0834
# Epoch 264/4000, Training Loss: 1.0489
# Val. confidence score: 0.0434, Val. loss: 0.8606, Avg. Uncertainty: 0.0762
# Epoch 265/4000, Training Loss: 1.0633
# Val. confidence score: 0.0483, Val. loss: 0.8602, Avg. Uncertainty: 0.0765
# Epoch 266/4000, Training Loss: 0.9697
# Val. confidence score: 0.0488, Val. loss: 0.8615, Avg. Uncertainty: 0.0781
# Epoch 267/4000, Training Loss: 0.9930
# Val. confidence score: 0.0570, Val. loss: 0.8562, Avg. Uncertainty: 0.0722
# Epoch 268/4000, Training Loss: 1.0592
# Val. confidence score: 0.0444, Val. loss: 0.8639, Avg. Uncertainty: 0.0711
# Epoch 269/4000, Training Loss: 0.9407
# Val. confidence score: 0.0536, Val. loss: 0.8577, Avg. Uncertainty: 0.0697
# Epoch 270/4000, Training Loss: 1.0229
# Val. confidence score: 0.0405, Val. loss: 0.8661, Avg. Uncertainty: 0.0754
# Epoch 271/4000, Training Loss: 0.9902
# Val. confidence score: 0.0437, Val. loss: 0.8633, Avg. Uncertainty: 0.0746
# Epoch 272/4000, Training Loss: 1.0075
# Val. confidence score: 0.0616, Val. loss: 0.8571, Avg. Uncertainty: 0.0765
# Epoch 273/4000, Training Loss: 1.0049
# Val. confidence score: 0.0561, Val. loss: 0.8570, Avg. Uncertainty: 0.0832
# Epoch 274/4000, Training Loss: 0.9855
# Val. confidence score: 0.0545, Val. loss: 0.8569, Avg. Uncertainty: 0.0662
# Epoch 275/4000, Training Loss: 1.0780
# Val. confidence score: 0.0557, Val. loss: 0.8563, Avg. Uncertainty: 0.0715
# Epoch 276/4000, Training Loss: 1.0685
# Val. confidence score: 0.0528, Val. loss: 0.8571, Avg. Uncertainty: 0.0709
# Epoch 277/4000, Training Loss: 1.0021
# Val. confidence score: 0.0623, Val. loss: 0.8526, Avg. Uncertainty: 0.0835
# Epoch 278/4000, Training Loss: 0.9970
# Val. confidence score: 0.0560, Val. loss: 0.8555, Avg. Uncertainty: 0.0749
# Epoch 279/4000, Training Loss: 1.0117
# Val. confidence score: 0.0477, Val. loss: 0.8611, Avg. Uncertainty: 0.0771
# Epoch 280/4000, Training Loss: 0.9721
# Val. confidence score: 0.0276, Val. loss: 0.8708, Avg. Uncertainty: 0.0647
# Epoch 281/4000, Training Loss: 0.9802
# Val. confidence score: 0.0413, Val. loss: 0.8657, Avg. Uncertainty: 0.0813
# Epoch 282/4000, Training Loss: 0.9623
# Val. confidence score: 0.0606, Val. loss: 0.8571, Avg. Uncertainty: 0.0820
# Epoch 283/4000, Training Loss: 1.0202
# Val. confidence score: 0.0540, Val. loss: 0.8603, Avg. Uncertainty: 0.0901
# Epoch 284/4000, Training Loss: 0.9620
# Val. confidence score: 0.0579, Val. loss: 0.8622, Avg. Uncertainty: 0.0897
# Epoch 285/4000, Training Loss: 0.9976
# Val. confidence score: 0.0392, Val. loss: 0.8657, Avg. Uncertainty: 0.0768
# Epoch 286/4000, Training Loss: 0.9842
# Val. confidence score: 0.0446, Val. loss: 0.8640, Avg. Uncertainty: 0.0864
# Epoch 287/4000, Training Loss: 1.0022
# Val. confidence score: 0.0388, Val. loss: 0.8670, Avg. Uncertainty: 0.0863
# Epoch 288/4000, Training Loss: 0.9442
# Val. confidence score: 0.0398, Val. loss: 0.8680, Avg. Uncertainty: 0.0910
# Epoch 289/4000, Training Loss: 1.0854
# Val. confidence score: 0.0297, Val. loss: 0.8702, Avg. Uncertainty: 0.0718
# Epoch 290/4000, Training Loss: 0.9821
# Val. confidence score: 0.0491, Val. loss: 0.8582, Avg. Uncertainty: 0.0740
# Epoch 291/4000, Training Loss: 0.9348
# Val. confidence score: 0.0570, Val. loss: 0.8563, Avg. Uncertainty: 0.0868
# Epoch 292/4000, Training Loss: 1.0404
# Val. confidence score: 0.0364, Val. loss: 0.8677, Avg. Uncertainty: 0.0778
# Epoch 293/4000, Training Loss: 1.0646
# Val. confidence score: 0.0601, Val. loss: 0.8531, Avg. Uncertainty: 0.0846
# Epoch 294/4000, Training Loss: 1.0135
# Val. confidence score: 0.0670, Val. loss: 0.8506, Avg. Uncertainty: 0.0882
# Epoch 295/4000, Training Loss: 0.9906
# Val. confidence score: 0.0679, Val. loss: 0.8489, Avg. Uncertainty: 0.0909
# Epoch 296/4000, Training Loss: 0.9850
# Val. confidence score: 0.0585, Val. loss: 0.8551, Avg. Uncertainty: 0.0830
# Epoch 297/4000, Training Loss: 1.0510
# Val. confidence score: 0.0474, Val. loss: 0.8598, Avg. Uncertainty: 0.0808
# Epoch 298/4000, Training Loss: 0.9373
# Val. confidence score: 0.0601, Val. loss: 0.8526, Avg. Uncertainty: 0.0745
# Epoch 299/4000, Training Loss: 0.9554
# Val. confidence score: 0.0652, Val. loss: 0.8500, Avg. Uncertainty: 0.0813
# Epoch 300/4000, Training Loss: 0.9639
# Val. confidence score: 0.0467, Val. loss: 0.8604, Avg. Uncertainty: 0.0856
# Epoch 301/4000, Training Loss: 0.9843
# Val. confidence score: 0.0439, Val. loss: 0.8600, Avg. Uncertainty: 0.0786
# Epoch 302/4000, Training Loss: 0.9951
# Val. confidence score: 0.0355, Val. loss: 0.8635, Avg. Uncertainty: 0.0671
# Epoch 303/4000, Training Loss: 0.9908
# Val. confidence score: 0.0389, Val. loss: 0.8633, Avg. Uncertainty: 0.0668
# Epoch 304/4000, Training Loss: 1.0194
# Val. confidence score: 0.0483, Val. loss: 0.8557, Avg. Uncertainty: 0.0745
# Epoch 305/4000, Training Loss: 1.0164
# Val. confidence score: 0.0424, Val. loss: 0.8619, Avg. Uncertainty: 0.0839
# Epoch 306/4000, Training Loss: 1.0293
# Val. confidence score: 0.0439, Val. loss: 0.8632, Avg. Uncertainty: 0.0890
# Epoch 307/4000, Training Loss: 1.0809
# Val. confidence score: 0.0533, Val. loss: 0.8582, Avg. Uncertainty: 0.0965
# Epoch 308/4000, Training Loss: 0.9986
# Val. confidence score: 0.0549, Val. loss: 0.8594, Avg. Uncertainty: 0.0828
# Epoch 309/4000, Training Loss: 0.9419
# Val. confidence score: 0.0535, Val. loss: 0.8551, Avg. Uncertainty: 0.0812
# Epoch 310/4000, Training Loss: 0.9945
# Val. confidence score: 0.0512, Val. loss: 0.8559, Avg. Uncertainty: 0.0830
# Epoch 311/4000, Training Loss: 1.0484
# Val. confidence score: 0.0387, Val. loss: 0.8609, Avg. Uncertainty: 0.0700
# Epoch 312/4000, Training Loss: 0.9794
# Val. confidence score: 0.0388, Val. loss: 0.8609, Avg. Uncertainty: 0.0657
# Epoch 313/4000, Training Loss: 0.9974
# Val. confidence score: 0.0436, Val. loss: 0.8582, Avg. Uncertainty: 0.0703
# Epoch 314/4000, Training Loss: 0.9947
# Val. confidence score: 0.0436, Val. loss: 0.8573, Avg. Uncertainty: 0.0676
# Epoch 315/4000, Training Loss: 1.0016
# Val. confidence score: 0.0348, Val. loss: 0.8634, Avg. Uncertainty: 0.0764
# Epoch 316/4000, Training Loss: 0.9570
# Val. confidence score: 0.0562, Val. loss: 0.8541, Avg. Uncertainty: 0.0837
# Epoch 317/4000, Training Loss: 0.9725
# Val. confidence score: 0.0502, Val. loss: 0.8527, Avg. Uncertainty: 0.0725
# Epoch 318/4000, Training Loss: 0.9820
# Val. confidence score: 0.0457, Val. loss: 0.8578, Avg. Uncertainty: 0.0784
# Epoch 319/4000, Training Loss: 1.0127
# Val. confidence score: 0.0418, Val. loss: 0.8571, Avg. Uncertainty: 0.0711
# Epoch 320/4000, Training Loss: 1.0277
# Val. confidence score: 0.0559, Val. loss: 0.8502, Avg. Uncertainty: 0.0717
# Epoch 321/4000, Training Loss: 0.9855
# Val. confidence score: 0.0555, Val. loss: 0.8511, Avg. Uncertainty: 0.0663
# Epoch 322/4000, Training Loss: 1.0307
# Val. confidence score: 0.0621, Val. loss: 0.8491, Avg. Uncertainty: 0.0795
# Epoch 323/4000, Training Loss: 0.9898
# Val. confidence score: 0.0572, Val. loss: 0.8541, Avg. Uncertainty: 0.0767
# Epoch 324/4000, Training Loss: 0.9836
# Val. confidence score: 0.0605, Val. loss: 0.8556, Avg. Uncertainty: 0.0884
# Epoch 325/4000, Training Loss: 1.0094
# Val. confidence score: 0.0571, Val. loss: 0.8533, Avg. Uncertainty: 0.0798
# Epoch 326/4000, Training Loss: 0.9967
# Val. confidence score: 0.0466, Val. loss: 0.8576, Avg. Uncertainty: 0.0731
# Epoch 327/4000, Training Loss: 1.0576
# Val. confidence score: 0.0533, Val. loss: 0.8563, Avg. Uncertainty: 0.0693
# Epoch 328/4000, Training Loss: 0.9601
# Val. confidence score: 0.0511, Val. loss: 0.8568, Avg. Uncertainty: 0.0724
# Epoch 329/4000, Training Loss: 0.9660
# Val. confidence score: 0.0496, Val. loss: 0.8567, Avg. Uncertainty: 0.0665
# Epoch 330/4000, Training Loss: 0.9998
# Val. confidence score: 0.0397, Val. loss: 0.8644, Avg. Uncertainty: 0.0702
# Epoch 331/4000, Training Loss: 0.9497
# Val. confidence score: 0.0390, Val. loss: 0.8618, Avg. Uncertainty: 0.0693
# Epoch 332/4000, Training Loss: 1.0163
# Val. confidence score: 0.0528, Val. loss: 0.8581, Avg. Uncertainty: 0.0738
# Epoch 333/4000, Training Loss: 0.9684
# Val. confidence score: 0.0429, Val. loss: 0.8614, Avg. Uncertainty: 0.0721
# Epoch 334/4000, Training Loss: 0.9845
# Val. confidence score: 0.0414, Val. loss: 0.8618, Avg. Uncertainty: 0.0727
# Epoch 335/4000, Training Loss: 0.9830
# Val. confidence score: 0.0418, Val. loss: 0.8614, Avg. Uncertainty: 0.0713
# Epoch 336/4000, Training Loss: 0.9840
# Val. confidence score: 0.0453, Val. loss: 0.8636, Avg. Uncertainty: 0.0732
# Epoch 337/4000, Training Loss: 1.0453
# Val. confidence score: 0.0334, Val. loss: 0.8704, Avg. Uncertainty: 0.0747
# Epoch 338/4000, Training Loss: 0.9820
# Val. confidence score: 0.0594, Val. loss: 0.8583, Avg. Uncertainty: 0.0833
# Epoch 339/4000, Training Loss: 0.9586
# Val. confidence score: 0.0506, Val. loss: 0.8645, Avg. Uncertainty: 0.0723
# Epoch 340/4000, Training Loss: 0.9161
# Val. confidence score: 0.0503, Val. loss: 0.8666, Avg. Uncertainty: 0.0831
# Epoch 341/4000, Training Loss: 0.9641
# Val. confidence score: 0.0421, Val. loss: 0.8724, Avg. Uncertainty: 0.0827
# Epoch 342/4000, Training Loss: 1.0350
# Val. confidence score: 0.0517, Val. loss: 0.8669, Avg. Uncertainty: 0.0818
# Epoch 343/4000, Training Loss: 1.0354
# Val. confidence score: 0.0481, Val. loss: 0.8638, Avg. Uncertainty: 0.0659
# Epoch 344/4000, Training Loss: 0.9829
# Val. confidence score: 0.0491, Val. loss: 0.8622, Avg. Uncertainty: 0.0691
# Epoch 345/4000, Training Loss: 0.9930
# Val. confidence score: 0.0495, Val. loss: 0.8596, Avg. Uncertainty: 0.0660
# Epoch 346/4000, Training Loss: 1.0451
# Val. confidence score: 0.0581, Val. loss: 0.8611, Avg. Uncertainty: 0.0712
# Epoch 347/4000, Training Loss: 0.9627
# Val. confidence score: 0.0476, Val. loss: 0.8636, Avg. Uncertainty: 0.0757
# Epoch 348/4000, Training Loss: 1.0050
# Val. confidence score: 0.0304, Val. loss: 0.8754, Avg. Uncertainty: 0.0786
# Epoch 349/4000, Training Loss: 0.9669
# Val. confidence score: 0.0440, Val. loss: 0.8704, Avg. Uncertainty: 0.0809
# Epoch 350/4000, Training Loss: 0.9800
# Val. confidence score: 0.0314, Val. loss: 0.8745, Avg. Uncertainty: 0.0746
# Epoch 351/4000, Training Loss: 0.9262
# Val. confidence score: 0.0493, Val. loss: 0.8674, Avg. Uncertainty: 0.0788
# Epoch 352/4000, Training Loss: 0.9897
# Val. confidence score: 0.0486, Val. loss: 0.8656, Avg. Uncertainty: 0.0819
# Epoch 353/4000, Training Loss: 0.9729
# Val. confidence score: 0.0563, Val. loss: 0.8588, Avg. Uncertainty: 0.0749
# Epoch 354/4000, Training Loss: 1.0616
# Val. confidence score: 0.0501, Val. loss: 0.8637, Avg. Uncertainty: 0.0721
# Epoch 355/4000, Training Loss: 0.9621
# Val. confidence score: 0.0548, Val. loss: 0.8650, Avg. Uncertainty: 0.0769
# Epoch 356/4000, Training Loss: 0.9224
# Val. confidence score: 0.0410, Val. loss: 0.8739, Avg. Uncertainty: 0.0903
# Epoch 357/4000, Training Loss: 1.0224
# Val. confidence score: 0.0451, Val. loss: 0.8713, Avg. Uncertainty: 0.0828
# Epoch 358/4000, Training Loss: 1.0878
# Val. confidence score: 0.0424, Val. loss: 0.8673, Avg. Uncertainty: 0.0629
# Epoch 359/4000, Training Loss: 0.9878
# Val. confidence score: 0.0491, Val. loss: 0.8679, Avg. Uncertainty: 0.0740
# Epoch 360/4000, Training Loss: 0.9454
# Val. confidence score: 0.0521, Val. loss: 0.8663, Avg. Uncertainty: 0.0803
# Epoch 361/4000, Training Loss: 0.9693
# Val. confidence score: 0.0415, Val. loss: 0.8764, Avg. Uncertainty: 0.0902
# Epoch 362/4000, Training Loss: 0.9456
# Val. confidence score: 0.0473, Val. loss: 0.8772, Avg. Uncertainty: 0.0871
# Epoch 363/4000, Training Loss: 0.9463
# Val. confidence score: 0.0489, Val. loss: 0.8710, Avg. Uncertainty: 0.0901
# Epoch 364/4000, Training Loss: 0.9819
# Val. confidence score: 0.0512, Val. loss: 0.8667, Avg. Uncertainty: 0.0727
# Epoch 365/4000, Training Loss: 0.9758
# Val. confidence score: 0.0553, Val. loss: 0.8617, Avg. Uncertainty: 0.0784
# Epoch 366/4000, Training Loss: 1.0968
# Val. confidence score: 0.0520, Val. loss: 0.8667, Avg. Uncertainty: 0.0920
# Epoch 367/4000, Training Loss: 1.0438
# Val. confidence score: 0.0652, Val. loss: 0.8574, Avg. Uncertainty: 0.0810
# Epoch 368/4000, Training Loss: 0.9910
# Val. confidence score: 0.0651, Val. loss: 0.8503, Avg. Uncertainty: 0.0761
# Epoch 369/4000, Training Loss: 1.0044
# Val. confidence score: 0.0446, Val. loss: 0.8600, Avg. Uncertainty: 0.0686
# Epoch 370/4000, Training Loss: 0.9380
# Val. confidence score: 0.0334, Val. loss: 0.8700, Avg. Uncertainty: 0.0684
# Epoch 371/4000, Training Loss: 0.9590
# Val. confidence score: 0.0429, Val. loss: 0.8675, Avg. Uncertainty: 0.0763
# Epoch 372/4000, Training Loss: 0.9571
# Val. confidence score: 0.0483, Val. loss: 0.8635, Avg. Uncertainty: 0.0820
# Epoch 373/4000, Training Loss: 0.9934
# Val. confidence score: 0.0502, Val. loss: 0.8658, Avg. Uncertainty: 0.0809
# Epoch 374/4000, Training Loss: 0.9804
# Val. confidence score: 0.0571, Val. loss: 0.8580, Avg. Uncertainty: 0.0698
# Epoch 375/4000, Training Loss: 1.0551
# Val. confidence score: 0.0547, Val. loss: 0.8600, Avg. Uncertainty: 0.0657
# Epoch 376/4000, Training Loss: 1.0671
# Val. confidence score: 0.0548, Val. loss: 0.8598, Avg. Uncertainty: 0.0732
# Epoch 377/4000, Training Loss: 1.0129
# Val. confidence score: 0.0572, Val. loss: 0.8591, Avg. Uncertainty: 0.0704
# Epoch 378/4000, Training Loss: 0.9402
# Val. confidence score: 0.0461, Val. loss: 0.8739, Avg. Uncertainty: 0.0823
# Epoch 379/4000, Training Loss: 0.9932
# Val. confidence score: 0.0185, Val. loss: 0.8787, Avg. Uncertainty: 0.0782
# Epoch 380/4000, Training Loss: 0.9469
# Val. confidence score: 0.0115, Val. loss: 0.8782, Avg. Uncertainty: 0.0694
# Epoch 381/4000, Training Loss: 1.0378
# Val. confidence score: 0.0265, Val. loss: 0.8663, Avg. Uncertainty: 0.0667
# Epoch 382/4000, Training Loss: 0.9910
# Val. confidence score: 0.0337, Val. loss: 0.8661, Avg. Uncertainty: 0.0694
# Epoch 383/4000, Training Loss: 0.9385
# Val. confidence score: 0.0297, Val. loss: 0.8694, Avg. Uncertainty: 0.0802
# Epoch 384/4000, Training Loss: 1.0044
# Val. confidence score: 0.0299, Val. loss: 0.8743, Avg. Uncertainty: 0.0840
# Epoch 385/4000, Training Loss: 0.9420
# Val. confidence score: 0.0316, Val. loss: 0.8713, Avg. Uncertainty: 0.0800
# Epoch 386/4000, Training Loss: 0.9678
# Val. confidence score: 0.0313, Val. loss: 0.8756, Avg. Uncertainty: 0.0839
# Epoch 387/4000, Training Loss: 0.9969
# Val. confidence score: 0.0191, Val. loss: 0.8850, Avg. Uncertainty: 0.0893
# Epoch 388/4000, Training Loss: 0.9334
# Val. confidence score: 0.0222, Val. loss: 0.8815, Avg. Uncertainty: 0.0815
# Epoch 389/4000, Training Loss: 0.9586
# Val. confidence score: 0.0339, Val. loss: 0.8770, Avg. Uncertainty: 0.0789
# Epoch 390/4000, Training Loss: 0.9855
# Val. confidence score: 0.0201, Val. loss: 0.8894, Avg. Uncertainty: 0.0878
# Epoch 391/4000, Training Loss: 1.0416
# Val. confidence score: 0.0423, Val. loss: 0.8798, Avg. Uncertainty: 0.0817
# Epoch 392/4000, Training Loss: 0.9487
# Val. confidence score: 0.0360, Val. loss: 0.8707, Avg. Uncertainty: 0.0720
# Epoch 393/4000, Training Loss: 1.0187
# Val. confidence score: 0.0415, Val. loss: 0.8727, Avg. Uncertainty: 0.0732
# Epoch 394/4000, Training Loss: 1.0305
# Val. confidence score: 0.0330, Val. loss: 0.8799, Avg. Uncertainty: 0.0763
# Epoch 395/4000, Training Loss: 0.9271
# Val. confidence score: 0.0416, Val. loss: 0.8762, Avg. Uncertainty: 0.0801
# Epoch 396/4000, Training Loss: 0.9866
# Val. confidence score: 0.0225, Val. loss: 0.8896, Avg. Uncertainty: 0.0861
# Epoch 397/4000, Training Loss: 1.1034
# Val. confidence score: 0.0258, Val. loss: 0.8806, Avg. Uncertainty: 0.0698
# Epoch 398/4000, Training Loss: 0.9883
# Val. confidence score: 0.0424, Val. loss: 0.8691, Avg. Uncertainty: 0.0647
# Epoch 399/4000, Training Loss: 0.9438
# Val. confidence score: 0.0352, Val. loss: 0.8723, Avg. Uncertainty: 0.0690
# Epoch 400/4000, Training Loss: 0.9711
# Val. confidence score: 0.0402, Val. loss: 0.8695, Avg. Uncertainty: 0.0775
# Epoch 401/4000, Training Loss: 0.9872
# Val. confidence score: 0.0249, Val. loss: 0.8790, Avg. Uncertainty: 0.0718
# Epoch 402/4000, Training Loss: 1.0007
# Val. confidence score: 0.0288, Val. loss: 0.8762, Avg. Uncertainty: 0.0779
# Epoch 403/4000, Training Loss: 0.9445
# Val. confidence score: 0.0400, Val. loss: 0.8714, Avg. Uncertainty: 0.0810
# Epoch 404/4000, Training Loss: 0.9311
# Val. confidence score: 0.0271, Val. loss: 0.8791, Avg. Uncertainty: 0.0789
# Epoch 405/4000, Training Loss: 0.9841
# Val. confidence score: 0.0292, Val. loss: 0.8773, Avg. Uncertainty: 0.0754
# Epoch 406/4000, Training Loss: 0.9968
# Val. confidence score: 0.0165, Val. loss: 0.8871, Avg. Uncertainty: 0.0985
# Epoch 407/4000, Training Loss: 0.9988
# Val. confidence score: 0.0186, Val. loss: 0.8800, Avg. Uncertainty: 0.0842
# Epoch 408/4000, Training Loss: 0.9360
# Val. confidence score: 0.0174, Val. loss: 0.8863, Avg. Uncertainty: 0.0794
# Epoch 409/4000, Training Loss: 0.9330
# Val. confidence score: 0.0134, Val. loss: 0.8905, Avg. Uncertainty: 0.0815
# Epoch 410/4000, Training Loss: 1.0163
# Val. confidence score: 0.0273, Val. loss: 0.8831, Avg. Uncertainty: 0.0908
# Epoch 411/4000, Training Loss: 0.9868
# Val. confidence score: 0.0152, Val. loss: 0.8879, Avg. Uncertainty: 0.0825
# Epoch 412/4000, Training Loss: 0.9759
# Val. confidence score: 0.0389, Val. loss: 0.8784, Avg. Uncertainty: 0.0791
# Epoch 413/4000, Training Loss: 0.9677
# Val. confidence score: 0.0135, Val. loss: 0.9003, Avg. Uncertainty: 0.0941
# Epoch 414/4000, Training Loss: 1.0228
# Val. confidence score: 0.0453, Val. loss: 0.8708, Avg. Uncertainty: 0.0806
# Epoch 415/4000, Training Loss: 1.1279
# Val. confidence score: 0.0296, Val. loss: 0.8783, Avg. Uncertainty: 0.0685
# Epoch 416/4000, Training Loss: 0.9603
# Val. confidence score: 0.0305, Val. loss: 0.8798, Avg. Uncertainty: 0.0787
# Epoch 417/4000, Training Loss: 0.9829
# Val. confidence score: 0.0159, Val. loss: 0.8881, Avg. Uncertainty: 0.0821
# Epoch 418/4000, Training Loss: 0.9476
# Val. confidence score: -0.0236, Val. loss: 0.9184, Avg. Uncertainty: 0.1059
# Epoch 419/4000, Training Loss: 0.9710
# Val. confidence score: 0.0137, Val. loss: 0.8890, Avg. Uncertainty: 0.0834
# Epoch 420/4000, Training Loss: 0.9839
# Val. confidence score: 0.0090, Val. loss: 0.8857, Avg. Uncertainty: 0.0821
# Epoch 421/4000, Training Loss: 0.9798
# Val. confidence score: -0.0243, Val. loss: 0.9061, Avg. Uncertainty: 0.0961
# Epoch 422/4000, Training Loss: 0.9567
# Val. confidence score: 0.0295, Val. loss: 0.8780, Avg. Uncertainty: 0.0748
# Epoch 423/4000, Training Loss: 0.9271
# Val. confidence score: 0.0012, Val. loss: 0.8924, Avg. Uncertainty: 0.0787
# Epoch 424/4000, Training Loss: 0.9595
# Val. confidence score: -0.0258, Val. loss: 0.9141, Avg. Uncertainty: 0.0950
# Epoch 425/4000, Training Loss: 0.9815
# ...
# Epoch 3862/4000, Training Loss: 0.5917
# Val. confidence score: -0.1336, Val. loss: 1.0083, Avg. Uncertainty: 0.0642
# Epoch 3863/4000, Training Loss: 0.5960
# Val. confidence score: -0.1331, Val. loss: 1.0088, Avg. Uncertainty: 0.0668
# Epoch 3864/4000, Training Loss: 0.6567
# Val. confidence score: -0.1507, Val. loss: 1.0193, Avg. Uncertainty: 0.0536
# Epoch 3865/4000, Training Loss: 0.6183
# Val. confidence score: -0.1381, Val. loss: 1.0066, Avg. Uncertainty: 0.0649
# Epoch 3866/4000, Training Loss: 0.6423
# Val. confidence score: -0.0848, Val. loss: 0.9658, Avg. Uncertainty: 0.0530
# Epoch 3867/4000, Training Loss: 0.5468
# Val. confidence score: -0.0704, Val. loss: 0.9574, Avg. Uncertainty: 0.0609
# Epoch 3868/4000, Training Loss: 0.5951
# Val. confidence score: -0.1254, Val. loss: 1.0025, Avg. Uncertainty: 0.0688
# Epoch 3869/4000, Training Loss: 0.5811
# Val. confidence score: -0.1909, Val. loss: 1.0406, Avg. Uncertainty: 0.0667
# Epoch 3870/4000, Training Loss: 0.6153
# Val. confidence score: -0.1595, Val. loss: 1.0045, Avg. Uncertainty: 0.0586
# Epoch 3871/4000, Training Loss: 0.5628
# Val. confidence score: -0.1930, Val. loss: 1.0255, Avg. Uncertainty: 0.0654
# Epoch 3872/4000, Training Loss: 0.6057
# Val. confidence score: -0.2347, Val. loss: 1.0461, Avg. Uncertainty: 0.0683
# Epoch 3873/4000, Training Loss: 0.6576
# Val. confidence score: -0.1746, Val. loss: 1.0022, Avg. Uncertainty: 0.0654
# Epoch 3874/4000, Training Loss: 0.5525
# Val. confidence score: -0.2001, Val. loss: 1.0173, Avg. Uncertainty: 0.0676
# Epoch 3875/4000, Training Loss: 0.6039
# Val. confidence score: -0.1499, Val. loss: 0.9795, Avg. Uncertainty: 0.0709
# Epoch 3876/4000, Training Loss: 0.6027
# Val. confidence score: -0.1466, Val. loss: 0.9775, Avg. Uncertainty: 0.0634
# Epoch 3877/4000, Training Loss: 0.6303
# Val. confidence score: -0.0847, Val. loss: 0.9401, Avg. Uncertainty: 0.0575
# Epoch 3878/4000, Training Loss: 0.5748
# Val. confidence score: -0.1290, Val. loss: 0.9816, Avg. Uncertainty: 0.0655
# Epoch 3879/4000, Training Loss: 0.6309
# Val. confidence score: -0.1281, Val. loss: 0.9773, Avg. Uncertainty: 0.0602
# Epoch 3880/4000, Training Loss: 0.6074
# Val. confidence score: -0.0895, Val. loss: 0.9490, Avg. Uncertainty: 0.0627
# Epoch 3881/4000, Training Loss: 0.5785
# Val. confidence score: -0.0718, Val. loss: 0.9329, Avg. Uncertainty: 0.0503
# Epoch 3882/4000, Training Loss: 0.6521
# Val. confidence score: -0.0900, Val. loss: 0.9497, Avg. Uncertainty: 0.0569
# Epoch 3883/4000, Training Loss: 0.5374
# Val. confidence score: -0.1042, Val. loss: 0.9713, Avg. Uncertainty: 0.0677
# Epoch 3884/4000, Training Loss: 0.5412
# Val. confidence score: -0.1043, Val. loss: 0.9878, Avg. Uncertainty: 0.0685
# Epoch 3885/4000, Training Loss: 0.5986
# Val. confidence score: -0.1492, Val. loss: 1.0131, Avg. Uncertainty: 0.0693
# Epoch 3886/4000, Training Loss: 0.5762
# Val. confidence score: -0.1383, Val. loss: 1.0029, Avg. Uncertainty: 0.0585
# Epoch 3887/4000, Training Loss: 0.6310
# Val. confidence score: -0.1036, Val. loss: 0.9811, Avg. Uncertainty: 0.0605
# Epoch 3888/4000, Training Loss: 0.6120
# Val. confidence score: -0.1118, Val. loss: 0.9935, Avg. Uncertainty: 0.0620
# Epoch 3889/4000, Training Loss: 0.7743
# Val. confidence score: -0.1097, Val. loss: 0.9892, Avg. Uncertainty: 0.0575
# Epoch 3890/4000, Training Loss: 0.6617
# Val. confidence score: -0.1810, Val. loss: 1.0433, Avg. Uncertainty: 0.0722
# Epoch 3891/4000, Training Loss: 0.6122
# Val. confidence score: -0.1003, Val. loss: 0.9868, Avg. Uncertainty: 0.0734
# Epoch 3892/4000, Training Loss: 0.6150
# Val. confidence score: -0.1066, Val. loss: 0.9979, Avg. Uncertainty: 0.0741
# Epoch 3893/4000, Training Loss: 0.6192
# Val. confidence score: -0.1094, Val. loss: 0.9877, Avg. Uncertainty: 0.0700
# Epoch 3894/4000, Training Loss: 0.5927
# Val. confidence score: -0.0962, Val. loss: 0.9719, Avg. Uncertainty: 0.0628
# Epoch 3895/4000, Training Loss: 0.6278
# Val. confidence score: -0.1246, Val. loss: 0.9860, Avg. Uncertainty: 0.0655
# Epoch 3896/4000, Training Loss: 0.6172
# Val. confidence score: -0.1302, Val. loss: 0.9877, Avg. Uncertainty: 0.0651
# Epoch 3897/4000, Training Loss: 0.5925
# Val. confidence score: -0.1791, Val. loss: 1.0157, Avg. Uncertainty: 0.0669
# Epoch 3898/4000, Training Loss: 0.6214
# Val. confidence score: -0.1876, Val. loss: 1.0217, Avg. Uncertainty: 0.0665
# Epoch 3899/4000, Training Loss: 0.5542
# Val. confidence score: -0.2071, Val. loss: 1.0307, Avg. Uncertainty: 0.0654
# Epoch 3900/4000, Training Loss: 0.5646
# Val. confidence score: -0.2099, Val. loss: 1.0339, Avg. Uncertainty: 0.0732
# Epoch 3901/4000, Training Loss: 0.5336
# Val. confidence score: -0.1401, Val. loss: 0.9845, Avg. Uncertainty: 0.0679
# Epoch 3902/4000, Training Loss: 0.5594
# Val. confidence score: -0.1156, Val. loss: 0.9722, Avg. Uncertainty: 0.0683
# Epoch 3903/4000, Training Loss: 0.5792
# Val. confidence score: -0.1154, Val. loss: 0.9780, Avg. Uncertainty: 0.0682
# Epoch 3904/4000, Training Loss: 0.5977
# Val. confidence score: -0.1052, Val. loss: 0.9685, Avg. Uncertainty: 0.0600
# Epoch 3905/4000, Training Loss: 0.5705
# Val. confidence score: -0.1316, Val. loss: 0.9898, Avg. Uncertainty: 0.0616
# Epoch 3906/4000, Training Loss: 0.5929
# Val. confidence score: -0.1371, Val. loss: 0.9980, Avg. Uncertainty: 0.0620
# Epoch 3907/4000, Training Loss: 0.6230
# Val. confidence score: -0.1450, Val. loss: 1.0102, Avg. Uncertainty: 0.0640
# Epoch 3908/4000, Training Loss: 0.5914
# Val. confidence score: -0.0998, Val. loss: 0.9708, Avg. Uncertainty: 0.0622
# Epoch 3909/4000, Training Loss: 0.5851
# Val. confidence score: -0.1015, Val. loss: 0.9711, Avg. Uncertainty: 0.0634
# Epoch 3910/4000, Training Loss: 0.5301
# Val. confidence score: -0.1369, Val. loss: 1.0030, Avg. Uncertainty: 0.0703
# Epoch 3911/4000, Training Loss: 0.5030
# Val. confidence score: -0.1569, Val. loss: 1.0295, Avg. Uncertainty: 0.0704
# Epoch 3912/4000, Training Loss: 0.6044
# Val. confidence score: -0.0606, Val. loss: 0.9508, Avg. Uncertainty: 0.0618
# Epoch 3913/4000, Training Loss: 0.6082
# Val. confidence score: -0.0717, Val. loss: 0.9637, Avg. Uncertainty: 0.0571
# Epoch 3914/4000, Training Loss: 0.7535
# Val. confidence score: -0.1138, Val. loss: 0.9954, Avg. Uncertainty: 0.0662
# Epoch 3915/4000, Training Loss: 0.6428
# Val. confidence score: -0.1373, Val. loss: 1.0064, Avg. Uncertainty: 0.0786
# Epoch 3916/4000, Training Loss: 0.6034
# Val. confidence score: -0.1598, Val. loss: 1.0212, Avg. Uncertainty: 0.0632
# Epoch 3917/4000, Training Loss: 0.6214
# Val. confidence score: -0.1699, Val. loss: 1.0301, Avg. Uncertainty: 0.0617
# Epoch 3918/4000, Training Loss: 0.5388
# Val. confidence score: -0.1765, Val. loss: 1.0255, Avg. Uncertainty: 0.0654
# Epoch 3919/4000, Training Loss: 0.6912
# Val. confidence score: -0.1102, Val. loss: 0.9874, Avg. Uncertainty: 0.0656
# Epoch 3920/4000, Training Loss: 0.5994
# Val. confidence score: -0.1372, Val. loss: 1.0101, Avg. Uncertainty: 0.0643
# Epoch 3921/4000, Training Loss: 0.5667
# Val. confidence score: -0.2032, Val. loss: 1.0616, Avg. Uncertainty: 0.0692
# Epoch 3922/4000, Training Loss: 0.6764
# Val. confidence score: -0.1273, Val. loss: 1.0098, Avg. Uncertainty: 0.0733
# Epoch 3923/4000, Training Loss: 0.6118
# Val. confidence score: -0.1154, Val. loss: 0.9891, Avg. Uncertainty: 0.0595
# Epoch 3924/4000, Training Loss: 0.5882
# Val. confidence score: -0.1021, Val. loss: 0.9704, Avg. Uncertainty: 0.0618
# Epoch 3925/4000, Training Loss: 0.5765
# Val. confidence score: -0.1183, Val. loss: 0.9839, Avg. Uncertainty: 0.0577
# Epoch 3926/4000, Training Loss: 0.5229
# Val. confidence score: -0.1817, Val. loss: 1.0471, Avg. Uncertainty: 0.0708
# Epoch 3927/4000, Training Loss: 0.5998
# Val. confidence score: -0.1492, Val. loss: 1.0225, Avg. Uncertainty: 0.0660
# Epoch 3928/4000, Training Loss: 0.5844
# Val. confidence score: -0.1011, Val. loss: 0.9745, Avg. Uncertainty: 0.0607
# Epoch 3929/4000, Training Loss: 0.6037
# Val. confidence score: -0.0858, Val. loss: 0.9662, Avg. Uncertainty: 0.0559
# Epoch 3930/4000, Training Loss: 0.5380
# Val. confidence score: -0.1082, Val. loss: 0.9907, Avg. Uncertainty: 0.0642
# Epoch 3931/4000, Training Loss: 0.5493
# Val. confidence score: -0.1748, Val. loss: 1.0359, Avg. Uncertainty: 0.0608
# Epoch 3932/4000, Training Loss: 0.6371
# Val. confidence score: -0.1253, Val. loss: 0.9972, Avg. Uncertainty: 0.0642
# Epoch 3933/4000, Training Loss: 0.6156
# Val. confidence score: -0.0797, Val. loss: 0.9706, Avg. Uncertainty: 0.0589
# Epoch 3934/4000, Training Loss: 0.6372
# Val. confidence score: -0.0908, Val. loss: 0.9825, Avg. Uncertainty: 0.0568
# Epoch 3935/4000, Training Loss: 0.5600
# Val. confidence score: -0.1244, Val. loss: 1.0138, Avg. Uncertainty: 0.0568
# Epoch 3936/4000, Training Loss: 0.5901
# Val. confidence score: -0.0657, Val. loss: 0.9668, Avg. Uncertainty: 0.0570
# Epoch 3937/4000, Training Loss: 0.6378
# Val. confidence score: -0.0456, Val. loss: 0.9548, Avg. Uncertainty: 0.0578
# Epoch 3938/4000, Training Loss: 0.6701
# Val. confidence score: -0.0642, Val. loss: 0.9662, Avg. Uncertainty: 0.0669
# Epoch 3939/4000, Training Loss: 0.6319
# Val. confidence score: -0.0656, Val. loss: 0.9539, Avg. Uncertainty: 0.0732
# Epoch 3940/4000, Training Loss: 0.6034
# Val. confidence score: -0.0739, Val. loss: 0.9390, Avg. Uncertainty: 0.0673
# Epoch 3941/4000, Training Loss: 0.6081
# Val. confidence score: -0.1026, Val. loss: 0.9487, Avg. Uncertainty: 0.0595
# Epoch 3942/4000, Training Loss: 0.6942
# Val. confidence score: -0.1056, Val. loss: 0.9412, Avg. Uncertainty: 0.0522
# Epoch 3943/4000, Training Loss: 0.6942
# Val. confidence score: -0.0965, Val. loss: 0.9371, Avg. Uncertainty: 0.0542
# Epoch 3944/4000, Training Loss: 0.5582
# Val. confidence score: -0.1313, Val. loss: 0.9533, Avg. Uncertainty: 0.0537
# Epoch 3945/4000, Training Loss: 0.6767
# Val. confidence score: -0.1283, Val. loss: 0.9561, Avg. Uncertainty: 0.0568
# Epoch 3946/4000, Training Loss: 0.5590
# Val. confidence score: -0.0926, Val. loss: 0.9400, Avg. Uncertainty: 0.0694
# Epoch 3947/4000, Training Loss: 0.5456
# Val. confidence score: -0.1039, Val. loss: 0.9528, Avg. Uncertainty: 0.0673
# Epoch 3948/4000, Training Loss: 0.6020
# Val. confidence score: -0.1193, Val. loss: 0.9558, Avg. Uncertainty: 0.0642
# Epoch 3949/4000, Training Loss: 0.6352
# Val. confidence score: -0.0944, Val. loss: 0.9369, Avg. Uncertainty: 0.0541
# Epoch 3950/4000, Training Loss: 0.5814
# Val. confidence score: -0.0720, Val. loss: 0.9305, Avg. Uncertainty: 0.0539
# Epoch 3951/4000, Training Loss: 0.5165
# Val. confidence score: -0.0844, Val. loss: 0.9353, Avg. Uncertainty: 0.0604
# Epoch 3952/4000, Training Loss: 0.5610
# Val. confidence score: -0.1283, Val. loss: 0.9571, Avg. Uncertainty: 0.0641
# Epoch 3953/4000, Training Loss: 0.5734
# Val. confidence score: -0.0909, Val. loss: 0.9431, Avg. Uncertainty: 0.0668
# Epoch 3954/4000, Training Loss: 0.5708
# Val. confidence score: -0.0984, Val. loss: 0.9506, Avg. Uncertainty: 0.0605
# Epoch 3955/4000, Training Loss: 0.5460
# Val. confidence score: -0.1112, Val. loss: 0.9517, Avg. Uncertainty: 0.0643
# Epoch 3956/4000, Training Loss: 0.5779
# Val. confidence score: -0.1007, Val. loss: 0.9428, Avg. Uncertainty: 0.0620
# Epoch 3957/4000, Training Loss: 0.5945
# Val. confidence score: -0.1026, Val. loss: 0.9340, Avg. Uncertainty: 0.0597
# Epoch 3958/4000, Training Loss: 0.5593
# Val. confidence score: -0.1811, Val. loss: 0.9772, Avg. Uncertainty: 0.0598
# Epoch 3959/4000, Training Loss: 0.5798
# Val. confidence score: -0.2287, Val. loss: 1.0277, Avg. Uncertainty: 0.0608
# Epoch 3960/4000, Training Loss: 0.5535
# Val. confidence score: -0.2082, Val. loss: 1.0210, Avg. Uncertainty: 0.0620
# Epoch 3961/4000, Training Loss: 0.5328
# Val. confidence score: -0.2088, Val. loss: 1.0178, Avg. Uncertainty: 0.0612
# Epoch 3962/4000, Training Loss: 0.6390
# Val. confidence score: -0.1809, Val. loss: 0.9990, Avg. Uncertainty: 0.0554
# Epoch 3963/4000, Training Loss: 0.5423
# Val. confidence score: -0.2602, Val. loss: 1.0542, Avg. Uncertainty: 0.0616
# Epoch 3964/4000, Training Loss: 0.5217
# Val. confidence score: -0.2149, Val. loss: 1.0214, Avg. Uncertainty: 0.0607
# Epoch 3965/4000, Training Loss: 0.6120
# Val. confidence score: -0.1632, Val. loss: 0.9830, Avg. Uncertainty: 0.0597
# Epoch 3966/4000, Training Loss: 0.5651
# Val. confidence score: -0.1417, Val. loss: 0.9748, Avg. Uncertainty: 0.0613
# Epoch 3967/4000, Training Loss: 0.6686
# Val. confidence score: -0.1157, Val. loss: 0.9577, Avg. Uncertainty: 0.0641
# Epoch 3968/4000, Training Loss: 0.5472
# Val. confidence score: -0.1150, Val. loss: 0.9543, Avg. Uncertainty: 0.0682
# Epoch 3969/4000, Training Loss: 0.5924
# Val. confidence score: -0.1591, Val. loss: 0.9868, Avg. Uncertainty: 0.0708
# Epoch 3970/4000, Training Loss: 0.6478
# Val. confidence score: -0.1563, Val. loss: 0.9818, Avg. Uncertainty: 0.0616
# Epoch 3971/4000, Training Loss: 0.5393
# Val. confidence score: -0.1068, Val. loss: 0.9494, Avg. Uncertainty: 0.0598
# Epoch 3972/4000, Training Loss: 0.5698
# Val. confidence score: -0.1086, Val. loss: 0.9608, Avg. Uncertainty: 0.0588
# Epoch 3973/4000, Training Loss: 0.7055
# Val. confidence score: -0.1946, Val. loss: 1.0095, Avg. Uncertainty: 0.0580
# Epoch 3974/4000, Training Loss: 0.5850
# Val. confidence score: -0.1418, Val. loss: 0.9620, Avg. Uncertainty: 0.0597
# Epoch 3975/4000, Training Loss: 0.5759
# Val. confidence score: -0.1370, Val. loss: 0.9656, Avg. Uncertainty: 0.0598
# Epoch 3976/4000, Training Loss: 0.5744
# Val. confidence score: -0.1517, Val. loss: 0.9793, Avg. Uncertainty: 0.0569
# Epoch 3977/4000, Training Loss: 0.7402
# Val. confidence score: -0.1438, Val. loss: 0.9668, Avg. Uncertainty: 0.0573
# Epoch 3978/4000, Training Loss: 0.5575
# Val. confidence score: -0.1897, Val. loss: 1.0067, Avg. Uncertainty: 0.0656
# Epoch 3979/4000, Training Loss: 0.5663
# Val. confidence score: -0.2166, Val. loss: 1.0170, Avg. Uncertainty: 0.0707
# Epoch 3980/4000, Training Loss: 0.5213
# Val. confidence score: -0.1835, Val. loss: 0.9988, Avg. Uncertainty: 0.0650
# Epoch 3981/4000, Training Loss: 0.5659
# Val. confidence score: -0.1386, Val. loss: 0.9711, Avg. Uncertainty: 0.0592
# Epoch 3982/4000, Training Loss: 0.6054
# Val. confidence score: -0.1580, Val. loss: 0.9826, Avg. Uncertainty: 0.0624
# Epoch 3983/4000, Training Loss: 0.5832
# Val. confidence score: -0.1281, Val. loss: 0.9638, Avg. Uncertainty: 0.0636
# Epoch 3984/4000, Training Loss: 0.5876
# Val. confidence score: -0.1283, Val. loss: 0.9557, Avg. Uncertainty: 0.0615
# Epoch 3985/4000, Training Loss: 0.4963
# Val. confidence score: -0.1395, Val. loss: 0.9711, Avg. Uncertainty: 0.0667
# Epoch 3986/4000, Training Loss: 0.5694
# Val. confidence score: -0.1886, Val. loss: 1.0112, Avg. Uncertainty: 0.0697
# Epoch 3987/4000, Training Loss: 0.5801
# Val. confidence score: -0.1979, Val. loss: 1.0272, Avg. Uncertainty: 0.0785
# Epoch 3988/4000, Training Loss: 0.4895
# Val. confidence score: -0.1378, Val. loss: 0.9898, Avg. Uncertainty: 0.0676
# Epoch 3989/4000, Training Loss: 0.5805
# Val. confidence score: -0.1409, Val. loss: 0.9992, Avg. Uncertainty: 0.0608
# Epoch 3990/4000, Training Loss: 0.6129
# Val. confidence score: -0.1552, Val. loss: 1.0055, Avg. Uncertainty: 0.0621
# Epoch 3991/4000, Training Loss: 0.6028
# Val. confidence score: -0.2182, Val. loss: 1.0445, Avg. Uncertainty: 0.0710
# Epoch 3992/4000, Training Loss: 0.5247
# Val. confidence score: -0.2263, Val. loss: 1.0489, Avg. Uncertainty: 0.0678
# Epoch 3993/4000, Training Loss: 0.5568
# Val. confidence score: -0.2322, Val. loss: 1.0334, Avg. Uncertainty: 0.0670
# Epoch 3994/4000, Training Loss: 0.6191
# Val. confidence score: -0.1845, Val. loss: 1.0055, Avg. Uncertainty: 0.0671
# Epoch 3995/4000, Training Loss: 0.5764
# Val. confidence score: -0.1786, Val. loss: 1.0008, Avg. Uncertainty: 0.0707
# Epoch 3996/4000, Training Loss: 0.5844
# Val. confidence score: -0.1725, Val. loss: 0.9839, Avg. Uncertainty: 0.0660
# Epoch 3997/4000, Training Loss: 0.5857
# Val. confidence score: -0.2013, Val. loss: 0.9910, Avg. Uncertainty: 0.0721
# Epoch 3998/4000, Training Loss: 0.5548
# Val. confidence score: -0.2351, Val. loss: 1.0179, Avg. Uncertainty: 0.0709
# Epoch 3999/4000, Training Loss: 0.5784
# Val. confidence score: -0.2139, Val. loss: 1.0013, Avg. Uncertainty: 0.0664
# Epoch 4000/4000, Training Loss: 0.6255
# Val. confidence score: -0.2200, Val. loss: 1.0130, Avg. Uncertainty: 0.0670

# %%
df.iloc[542]
# Out:
# Pregnancies                 10.000
# Glucose                     90.000
# BloodPressure               85.000
# SkinThickness               32.000
# Insulin                      0.000
# BMI                         34.900
# DiabetesPedigreeFunction     0.825
# Age                         56.000
# Outcome                      1.000
# Name: 542, dtype: float64

# %%
# Define the function for prediction with uncertainty
def predict_diabetes_progression(model, data, feature_scaler, target_scaler=None, mc_samples=100):
    """
    Predict diabetes progression and uncertainty using MC Dropout
    
    Args:
        model: Trained BNN model
        data: Input data for prediction (DataFrame or dict)
        feature_scaler: Scaler used for features during training
        target_scaler: Optional scaler for target (if used during training)
        mc_samples: Number of Monte Carlo samples
        
    Returns:
        predicted_value: Predicted progression value
        uncertainty: Standard deviation of predictions
    """
    model.eval()
    predictions = []
    
    # Convert input to DataFrame if it's a dictionary
    if isinstance(data, dict):
        data = pd.DataFrame([data])
    
    # Scale features
    scaled_data = feature_scaler.transform(data.values)
    input_tensor = torch.tensor(scaled_data, dtype=torch.float32)
    
    with torch.no_grad():
        for _ in range(mc_samples):
            pred = model(input_tensor, mc_dropout=True)
            predictions.append(pred.item())
    
    predictions = np.array(predictions)
    predicted_value = predictions.mean()
    uncertainty = predictions.std()
    
    # Inverse transform if target was scaled
    if target_scaler is not None:
        predicted_value = target_scaler.inverse_transform([[predicted_value]])[0][0]
        uncertainty = uncertainty * target_scaler.scale_[0]
    
    return predicted_value, uncertainty

# Example new patient data (using your row structure)
new_patient = {
    'Pregnancies': 10,
    'Glucose': 90,
    'BloodPressure': 85,
    'SkinThickness': 32,
    'Insulin': 0,
    'BMI': 34.9,
    'DiabetesPedigreeFunction': 0.825,
    'Age': 56
}

# Convert to DataFrame
patient_df = pd.DataFrame([new_patient])

# Make prediction
predicted_progression, uncertainty = predict_diabetes_progression(
    model=model,
    data=patient_df,
    feature_scaler=feature_scaler,  # Your feature scaler from training
    target_scaler=target_scaler,    # Your target scaler (if used)
    mc_samples=50
)

# Print results
print(f"\nPredicted Diabetes Progression: {predicted_progression:.1f}")
print(f"Uncertainty: ±{uncertainty:.1f}")
print("Interpretation:")
print("- Higher values indicate faster disease progression")
print(f"- 95% confidence interval: [{predicted_progression-2*uncertainty:.1f}, {predicted_progression+2*uncertainty:.1f}]")
# Out:
# Predicted Diabetes Progression: 0.7
# Uncertainty: ±0.5
# Interpretation:
# - Higher values indicate faster disease progression
# - 95% confidence interval: [-0.3, 1.6]
